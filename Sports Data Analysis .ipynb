# %% [markdown]
# # Matches Dataframe Analysis

# %%
import pandas as pd

# %%
matches = pd.read_csv(r"D:\DATA ANALYTICS\Internship\Sparks Foundation\Sports_EDA\Indian_Premier_League\matches.csv")
matches
# Out:
#         id  season           city        date                        team1  \
# 0        1    2017      Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1        2    2017           Pune  2017-04-06               Mumbai Indians
# 2        3    2017         Rajkot  2017-04-07                Gujarat Lions
# 3        4    2017         Indore  2017-04-08       Rising Pune Supergiant
# 4        5    2017      Bangalore  2017-04-08  Royal Challengers Bangalore
# ..     ...     ...            ...         ...                          ...
# 751  11347    2019         Mumbai    05/05/19        Kolkata Knight Riders
# 752  11412    2019        Chennai    07/05/19          Chennai Super Kings
# 753  11413    2019  Visakhapatnam    08/05/19          Sunrisers Hyderabad
# 754  11414    2019  Visakhapatnam    10/05/19               Delhi Capitals
# 755  11415    2019      Hyderabad    12/05/19               Mumbai Indians
#
# ...

# %%
matches.columns
# Out:
# Index(['id', 'season', 'city', 'date', 'team1', 'team2', 'toss_winner',
#        'toss_decision', 'result', 'dl_applied', 'winner', 'win_by_runs',
#        'win_by_wickets', 'player_of_match', 'venue', 'umpire1', 'umpire2',
#        'umpire3'],
#       dtype='object')

# %%
matches.dtypes
# Out:
# id                  int64
# season              int64
# city               object
# date               object
# team1              object
# team2              object
# toss_winner        object
# toss_decision      object
# result             object
# dl_applied          int64
# winner             object
# win_by_runs         int64
# win_by_wickets      int64
# player_of_match    object
# venue              object
# umpire1            object
# umpire2            object
# umpire3            object
# dtype: object

# %%
matches.shape
# Out:
# (756, 18)

# %%
type(matches.shape)
# Out:
# tuple

# %%
matches.head()
# Out:
#    id  season       city        date                        team1  \
# 0   1    2017  Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1   2    2017       Pune  2017-04-06               Mumbai Indians
# 2   3    2017     Rajkot  2017-04-07                Gujarat Lions
# 3   4    2017     Indore  2017-04-08       Rising Pune Supergiant
# 4   5    2017  Bangalore  2017-04-08  Royal Challengers Bangalore
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1       Rising Pune Supergiant       Rising Pune Supergiant         field
# 2        Kolkata Knight Riders        Kolkata Knight Riders         field
# 3              Kings XI Punjab              Kings XI Punjab         field
# 4             Delhi Daredevils  Royal Challengers Bangalore           bat
#
#    result  dl_applied                       winner  win_by_runs  \
# ...

# %%
matches.tail()
# Out:
#         id  season           city      date                  team1  \
# 751  11347    2019         Mumbai  05/05/19  Kolkata Knight Riders
# 752  11412    2019        Chennai  07/05/19    Chennai Super Kings
# 753  11413    2019  Visakhapatnam  08/05/19    Sunrisers Hyderabad
# 754  11414    2019  Visakhapatnam  10/05/19         Delhi Capitals
# 755  11415    2019      Hyderabad  12/05/19         Mumbai Indians
#
#                    team2          toss_winner toss_decision  result  \
# 751       Mumbai Indians       Mumbai Indians         field  normal
# 752       Mumbai Indians  Chennai Super Kings           bat  normal
# 753       Delhi Capitals       Delhi Capitals         field  normal
# 754  Chennai Super Kings  Chennai Super Kings         field  normal
# 755  Chennai Super Kings       Mumbai Indians           bat  normal
#
#      dl_applied               winner  win_by_runs  win_by_wickets  \
# 751           0       Mumbai Indians            0               9
# ...

# %%
matches.describe()
# Out:
#                  id       season  dl_applied  win_by_runs  win_by_wickets
# count    756.000000   756.000000  756.000000   756.000000      756.000000
# mean    1792.178571  2013.444444    0.025132    13.283069        3.350529
# std     3464.478148     3.366895    0.156630    23.471144        3.387963
# min        1.000000  2008.000000    0.000000     0.000000        0.000000
# 25%      189.750000  2011.000000    0.000000     0.000000        0.000000
# 50%      378.500000  2013.000000    0.000000     0.000000        4.000000
# 75%      567.250000  2016.000000    0.000000    19.000000        6.000000
# max    11415.000000  2019.000000    1.000000   146.000000       10.000000

# %%
matches.isnull().sum()
# Out:
# id                   0
# season               0
# city                 0
# date                 0
# team1                0
# team2                0
# toss_winner          0
# toss_decision        0
# result               0
# dl_applied           0
# winner               0
# win_by_runs          0
# win_by_wickets       0
# player_of_match      0
# venue                0
# umpire1              2
# umpire2              2
# umpire3            637
# dtype: int64

# %%
matches["winner"].fillna("No Results",inplace=True)

# %%
matches.describe()
# Out:
#                  id       season  dl_applied  win_by_runs  win_by_wickets
# count    756.000000   756.000000  756.000000   756.000000      756.000000
# mean    1792.178571  2013.444444    0.025132    13.283069        3.350529
# std     3464.478148     3.366895    0.156630    23.471144        3.387963
# min        1.000000  2008.000000    0.000000     0.000000        0.000000
# 25%      189.750000  2011.000000    0.000000     0.000000        0.000000
# 50%      378.500000  2013.000000    0.000000     0.000000        4.000000
# 75%      567.250000  2016.000000    0.000000    19.000000        6.000000
# max    11415.000000  2019.000000    1.000000   146.000000       10.000000

# %%
matches.isnull().sum()
# Out:
# id                   0
# season               0
# city                 0
# date                 0
# team1                0
# team2                0
# toss_winner          0
# toss_decision        0
# result               0
# dl_applied           0
# winner               0
# win_by_runs          0
# win_by_wickets       0
# player_of_match      0
# venue                0
# umpire1              2
# umpire2              2
# umpire3            637
# dtype: int64

# %%
rows_with_null_city = matches[matches['city'].isnull()]
print(rows_with_null_city)
# Out:
# Empty DataFrame
# Columns: [id, season, city, date, team1, team2, toss_winner, toss_decision, result, dl_applied, winner, win_by_runs, win_by_wickets, player_of_match, venue, umpire1, umpire2, umpire3]
# Index: []

# %%
matches["city"].fillna("United Arab Emirates",inplace=True)

# %%
matches.isnull().sum()
# Out:
# id                   0
# season               0
# city                 0
# date                 0
# team1                0
# team2                0
# toss_winner          0
# toss_decision        0
# result               0
# dl_applied           0
# winner               0
# win_by_runs          0
# win_by_wickets       0
# player_of_match      0
# venue                0
# umpire1              2
# umpire2              2
# umpire3            637
# dtype: int64

# %%
matches["player_of_match"].fillna("No Results",inplace=True)

# %%
matches.isnull().sum()
# Out:
# id                   0
# season               0
# city                 0
# date                 0
# team1                0
# team2                0
# toss_winner          0
# toss_decision        0
# result               0
# dl_applied           0
# winner               0
# win_by_runs          0
# win_by_wickets       0
# player_of_match      0
# venue                0
# umpire1              2
# umpire2              2
# umpire3            637
# dtype: int64

# %% [markdown]
# # Deliveries Dataframe Analysis

# %%
deliveries = pd.read_csv(r"D:\DATA ANALYTICS\Internship\Sparks Foundation\Sports_EDA\Indian_Premier_League\deliveries.csv")

# %%
match_13 = deliveries[deliveries['match_id']== 13]
match_13
# Out:
#       match_id  inning            batting_team            bowling_team  over  \
# 2832        13       1  Rising Pune Supergiant           Gujarat Lions     1
# 2833        13       1  Rising Pune Supergiant           Gujarat Lions     1
# 2834        13       1  Rising Pune Supergiant           Gujarat Lions     1
# 2835        13       1  Rising Pune Supergiant           Gujarat Lions     1
# 2836        13       1  Rising Pune Supergiant           Gujarat Lions     1
# ...        ...     ...                     ...                     ...   ...
# 3063        13       2           Gujarat Lions  Rising Pune Supergiant    18
# 3064        13       2           Gujarat Lions  Rising Pune Supergiant    18
# 3065        13       2           Gujarat Lions  Rising Pune Supergiant    18
# 3066        13       2           Gujarat Lions  Rising Pune Supergiant    18
# 3067        13       2           Gujarat Lions  Rising Pune Supergiant    18
#
# ...

# %%
deliveries.head()
# Out:
#    match_id  inning         batting_team                 bowling_team  over  \
# 0         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 1         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 2         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 3         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 4         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
#
#    ball    batsman non_striker    bowler  is_super_over  ...  bye_runs  \
# 0     1  DA Warner    S Dhawan  TS Mills              0  ...         0
# 1     2  DA Warner    S Dhawan  TS Mills              0  ...         0
# 2     3  DA Warner    S Dhawan  TS Mills              0  ...         0
# 3     4  DA Warner    S Dhawan  TS Mills              0  ...         0
# 4     5  DA Warner    S Dhawan  TS Mills              0  ...         0
#
#    legbye_runs  noball_runs  penalty_runs  batsman_runs  extra_runs  \
# ...

# %%
deliveries.tail()
# Out:
#         match_id  inning         batting_team    bowling_team  over  ball  \
# 179073     11415       2  Chennai Super Kings  Mumbai Indians    20     2
# 179074     11415       2  Chennai Super Kings  Mumbai Indians    20     3
# 179075     11415       2  Chennai Super Kings  Mumbai Indians    20     4
# 179076     11415       2  Chennai Super Kings  Mumbai Indians    20     5
# 179077     11415       2  Chennai Super Kings  Mumbai Indians    20     6
#
#           batsman non_striker      bowler  is_super_over  ...  bye_runs  \
# 179073  RA Jadeja   SR Watson  SL Malinga              0  ...         0
# 179074  SR Watson   RA Jadeja  SL Malinga              0  ...         0
# 179075  SR Watson   RA Jadeja  SL Malinga              0  ...         0
# 179076  SN Thakur   RA Jadeja  SL Malinga              0  ...         0
# 179077  SN Thakur   RA Jadeja  SL Malinga              0  ...         0
#
#         legbye_runs  noball_runs  penalty_runs  batsman_runs  extra_runs  \
# ...

# %%
deliveries.describe()
# Out:
#             match_id         inning           over           ball  \
# count  179078.000000  179078.000000  179078.000000  179078.000000
# mean     1802.252957       1.482952      10.162488       3.615587
# std      3472.322805       0.502074       5.677684       1.806966
# min         1.000000       1.000000       1.000000       1.000000
# 25%       190.000000       1.000000       5.000000       2.000000
# 50%       379.000000       1.000000      10.000000       4.000000
# 75%       567.000000       2.000000      15.000000       5.000000
# max     11415.000000       5.000000      20.000000       9.000000
#
#        is_super_over      wide_runs       bye_runs    legbye_runs  \
# count  179078.000000  179078.000000  179078.000000  179078.000000
# mean        0.000452       0.036721       0.004936       0.021136
# std         0.021263       0.251161       0.116480       0.194908
# min         0.000000       0.000000       0.000000       0.000000
# ...

# %%
len(deliveries)
# Out:
# 179078

# %%
deliveries.isnull().sum()
# Out:
# match_id                 0
# inning                   0
# batting_team             0
# bowling_team             0
# over                     0
# ball                     0
# batsman                  0
# non_striker              0
# bowler                   0
# is_super_over            0
# wide_runs                0
# bye_runs                 0
# legbye_runs              0
# noball_runs              0
# penalty_runs             0
# batsman_runs             0
# extra_runs               0
# total_runs               0
# player_dismissed    170244
# dismissal_kind      170244
# fielder             172630
# dtype: int64

# %% [markdown]
# # Matches Analysis

# %%
MostMatchesinSeason = matches["season"].value_counts().reset_index()
MostMatchesinSeason.columns = ["season","Number_of_Matches"]
MostMatchesinSeason = MostMatchesinSeason.sort_values(by="Number_of_Matches",ascending = False)
MostMatchesinSeason
# Out:
#     season  Number_of_Matches
# 0     2013                 76
# 1     2012                 74
# 2     2011                 73
# 3     2010                 60
# 4     2014                 60
# 5     2016                 60
# 6     2018                 60
# 7     2019                 60
# 8     2017                 59
# 9     2015                 59
# 10    2008                 58
# 11    2009                 57

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(12, 6))
bars = plt.bar(MostMatchesinSeason['season'], MostMatchesinSeason['Number_of_Matches'], color='purple')
plt.xlabel('season')
plt.ylabel('Number of Matches')
plt.title('Number of Matches Played in Each Season')
plt.xticks(MostMatchesinSeason['season'], rotation=45, ha='right')  # Set the x-axis labels in the desired order
plt.tight_layout()

for bar in bars:
    plt.annotate(str(bar.get_height()), (bar.get_x() + bar.get_width() / 2, bar.get_height()), ha='center', va='bottom')

plt.show()

# %% [markdown]
# ### Most matches were played in 2013 season that is 76.

# %%
matches_2013 = matches[matches['season'] == 2013]
teams_played_2013 = pd.concat([matches_2013['team1'], matches_2013['team2']]).unique()
print(teams_played_2013)
# Out:
# ['Delhi Daredevils' 'Royal Challengers Bangalore' 'Sunrisers Hyderabad'
#  'Rajasthan Royals' 'Mumbai Indians' 'Pune Warriors' 'Kings XI Punjab'
#  'Kolkata Knight Riders' 'Chennai Super Kings']

# %%
matches_2011 = matches[matches['season'] == 2011]
teams_played_2011 = pd.concat([matches_2011['team1'], matches_2011['team2']]).unique()
print(teams_played_2011)
# Out:
# ['Chennai Super Kings' 'Deccan Chargers' 'Kochi Tuskers Kerala'
#  'Delhi Daredevils' 'Kings XI Punjab' 'Kolkata Knight Riders'
#  'Royal Challengers Bangalore' 'Rajasthan Royals' 'Mumbai Indians'
#  'Pune Warriors']

# %%
matches_2008 = matches[matches['season'] == 2008]
teams_played_2008 = pd.concat([matches_2008['team1'], matches_2008['team2']]).unique()
print(teams_played_2008)
# Out:
# ['Kolkata Knight Riders' 'Chennai Super Kings' 'Rajasthan Royals'
#  'Mumbai Indians' 'Deccan Chargers' 'Kings XI Punjab'
#  'Royal Challengers Bangalore' 'Delhi Daredevils']

# %%
match_team_total_runs = deliveries.groupby(['match_id', 'batting_team'])['total_runs'].sum().reset_index()
match_team_total_runs
# Out:
#       match_id                 batting_team  total_runs
# 0            1  Royal Challengers Bangalore         172
# 1            1          Sunrisers Hyderabad         207
# 2            2               Mumbai Indians         184
# 3            2       Rising Pune Supergiant         187
# 4            3                Gujarat Lions         183
# ...        ...                          ...         ...
# 1505     11413          Sunrisers Hyderabad         171
# 1506     11414          Chennai Super Kings         162
# 1507     11414               Delhi Capitals         155
# 1508     11415          Chennai Super Kings         157
# 1509     11415               Mumbai Indians         152
#
# [1510 rows x 3 columns]

# %%
highest_runs_by_team = match_team_total_runs.sort_values(by='total_runs',ascending = False).head(10)
highest_runs_by_team
# Out:
#       match_id                 batting_team  total_runs
# 820        411  Royal Challengers Bangalore         263
# 1357      7937        Kolkata Knight Riders         250
# 1237       620  Royal Challengers Bangalore         248
# 410        206          Chennai Super Kings         246
# 1482     11338        Kolkata Knight Riders         241
# 120         61          Chennai Super Kings         240
# 1121       562  Royal Challengers Bangalore         235
# 1411     11147          Sunrisers Hyderabad         233
# 590        296              Kings XI Punjab         232
# 1485     11339          Sunrisers Hyderabad         232

# %% [markdown]
# ### Highest runs scored by team in an innings is 263 that is Royal Challengers Bangalore

# %%
superover_matches= deliveries[deliveries['is_super_over']== 1]
superover_matches
# Out:
#         match_id  inning      batting_team      bowling_team  over  ball  \
# 8092          34       3    Mumbai Indians     Gujarat Lions     1     1
# 8093          34       3    Mumbai Indians     Gujarat Lions     1     2
# 8094          34       3    Mumbai Indians     Gujarat Lions     1     3
# 8095          34       3    Mumbai Indians     Gujarat Lions     1     4
# 8096          34       3    Mumbai Indians     Gujarat Lions     1     5
# ...          ...     ...               ...               ...   ...   ...
# 127365       536       3   Kings XI Punjab  Rajasthan Royals     1     7
# 127366       536       4  Rajasthan Royals   Kings XI Punjab     1     1
# 127367       536       4  Rajasthan Royals   Kings XI Punjab     1     2
# 127368       536       4  Rajasthan Royals   Kings XI Punjab     1     3
# 127369       536       4  Rajasthan Royals   Kings XI Punjab     1     4
#
#             batsman  non_striker       bowler  is_super_over  ...  bye_runs  \
# ...

# %%
superover_matches = deliveries[deliveries['is_super_over'] == 1]
superover_results = superover_matches.merge(matches[['id', 'winner']], left_on='match_id', right_on='id')
superover_winners = superover_results[['match_id', 'batting_team', 'bowling_team', 'winner']]
print(superover_winners)
# Out:
#     match_id      batting_team      bowling_team           winner
# 0         34    Mumbai Indians     Gujarat Lions   Mumbai Indians
# 1         34    Mumbai Indians     Gujarat Lions   Mumbai Indians
# 2         34    Mumbai Indians     Gujarat Lions   Mumbai Indians
# 3         34    Mumbai Indians     Gujarat Lions   Mumbai Indians
# 4         34    Mumbai Indians     Gujarat Lions   Mumbai Indians
# ..       ...               ...               ...              ...
# 76       536   Kings XI Punjab  Rajasthan Royals  Kings XI Punjab
# 77       536  Rajasthan Royals   Kings XI Punjab  Kings XI Punjab
# 78       536  Rajasthan Royals   Kings XI Punjab  Kings XI Punjab
# 79       536  Rajasthan Royals   Kings XI Punjab  Kings XI Punjab
# 80       536  Rajasthan Royals   Kings XI Punjab  Kings XI Punjab
#
# [81 rows x 4 columns]

# %%
superover_matches = deliveries[deliveries['is_super_over'] == 1]
superover_results = superover_matches.merge(matches[['id', 'winner']], left_on='match_id', right_on='id')
superover_summary = superover_results.groupby('match_id').agg({
    'batting_team': lambda x: x.unique()[0],
    'bowling_team': lambda x: x.unique()[0],  
    'winner': 'first'
}).reset_index()
print(superover_summary)
# Out:
#    match_id                 batting_team                 bowling_team  \
# 0        34               Mumbai Indians                Gujarat Lions
# 1       126        Kolkata Knight Riders             Rajasthan Royals
# 2       190          Chennai Super Kings              Kings XI Punjab
# 3       388          Sunrisers Hyderabad  Royal Challengers Bangalore
# 4       401  Royal Challengers Bangalore             Delhi Daredevils
# 5       476        Kolkata Knight Riders             Rajasthan Royals
# 6       536              Kings XI Punjab             Rajasthan Royals
#
#                         winner
# 0               Mumbai Indians
# 1             Rajasthan Royals
# 2              Kings XI Punjab
# 3          Sunrisers Hyderabad
# 4  Royal Challengers Bangalore
# 5             Rajasthan Royals
# 6              Kings XI Punjab

# %%
# Count total matches played in each city by each team
total_matches_bycity = matches.groupby(['city', 'team1'])['id'].count().reset_index()
total_matches_bycity.columns = ['city', 'team', 'total_matches']
total_matches_bycity = total_matches_bycity.sort_values(by='total_matches',ascending = False)
total_matches_bycity
# Out:
#            city                             team  total_matches
# 156      Mumbai                   Mumbai Indians             47
# 70        Delhi  Delhi Daredevils/Delhi Capitals             43
# 138     Kolkata            Kolkata Knight Riders             41
# 55      Chennai              Chennai Super Kings             34
# 22    Bangalore      Royal Challengers Bangalore             33
# ..          ...                              ...            ...
# 52   Chandigarh           Rising Pune Supergiant              1
# 56      Chennai                  Deccan Chargers              1
# 137     Kolkata             Kochi Tuskers Kerala              1
# 57      Chennai  Delhi Daredevils/Delhi Capitals              1
# 40    Centurion                  Kings XI Punjab              1
#
# [211 rows x 3 columns]

# %% [markdown]
# ## Team Analysis:

# %%
matches.replace('Rising Pune Supergiants', 'Rising Pune Supergiant', inplace=True)

# %%
matches.replace('Delhi Capitals', 'Delhi Daredevils/Delhi Capitals', inplace=True)

# %%
matches.replace('Delhi Daredevils', 'Delhi Daredevils/Delhi Capitals', inplace=True)

# %%
most_wins = matches['winner'].value_counts().idxmax()
most_wins
# Out:
# 'Mumbai Indians'

# %%
win_counts = matches['winner'].value_counts().reset_index()
win_counts.columns = ['Team', 'Wins']
mostwon_teams = win_counts.sort_values(by='Wins', ascending=False)
mostwon_teams
# Out:
#                                Team  Wins
# 0                    Mumbai Indians   109
# 1               Chennai Super Kings   100
# 2             Kolkata Knight Riders    92
# 3       Royal Challengers Bangalore    84
# 4                   Kings XI Punjab    82
# 5   Delhi Daredevils/Delhi Capitals    77
# 6                  Rajasthan Royals    75
# 7               Sunrisers Hyderabad    58
# 8                   Deccan Chargers    29
# 9            Rising Pune Supergiant    15
# 10                    Gujarat Lions    13
# 11                    Pune Warriors    12
# 12             Kochi Tuskers Kerala     6
# 13                       No Results     4

# %%
most_won_team = matches['winner'].value_counts().idxmax()
most_won_team
# Out:
# 'Mumbai Indians'

# %% [markdown]
# ### Mumbai Indians has won the most matches in IPL.

# %%
second_most_won_team = mostwon_teams.iloc[1]
second_most_won_team
# Out:
# Team    Chennai Super Kings
# Wins                    100
# Name: 1, dtype: object

# %%
import matplotlib.pyplot as plt

# %%
# Create a bar chart with adjusted figure size and spacing
plt.figure(figsize=(12, 6))
bars = plt.bar(mostwon_teams['Team'], mostwon_teams['Wins'], color='green')
plt.xlabel('Team')
plt.ylabel('Wins')
plt.title('Wins by Team')
plt.xticks(rotation=45, ha='right')  # Rotate x-axis labels and align them to the right
plt.tight_layout()

# Annotate the bars with win counts
for bar in bars:
    plt.annotate(str(bar.get_height()), (bar.get_x() + bar.get_width() / 2, bar.get_height()), ha='center', va='bottom')

# Display the bar chart
plt.show()

# %%
matches_playedby_each_team1 = matches['team1'].value_counts().reset_index()
matches_playedby_each_team1.columns=['Team','matches_played']
matches_playedby_each_team1 = matches_playedby_each_team1.sort_values(by='matches_played',ascending = False)
matches_playedby_each_team1
# Out:
#                                Team  matches_played
# 0                    Mumbai Indians             101
# 1                   Kings XI Punjab              91
# 2               Chennai Super Kings              89
# 3       Royal Challengers Bangalore              85
# 4             Kolkata Knight Riders              83
# 5   Delhi Daredevils/Delhi Capitals              78
# 6                  Rajasthan Royals              67
# 7               Sunrisers Hyderabad              63
# 8                   Deccan Chargers              43
# 9                     Pune Warriors              20
# 10           Rising Pune Supergiant              15
# 11                    Gujarat Lions              14
# 12             Kochi Tuskers Kerala               7

# %% [markdown]
# ### Mumbai Indians has played the most matches in IPL

# %%
matches_playedby_each_team2 = matches['team2'].value_counts().reset_index()
matches_playedby_each_team2.columns=['Team','matches_played']
matches_playedby_each_team2 = matches_playedby_each_team2.sort_values(by='matches_played',ascending = False)
matches_playedby_each_team2
# Out:
#                                Team  matches_played
# 0   Delhi Daredevils/Delhi Capitals              99
# 1       Royal Challengers Bangalore              95
# 2             Kolkata Knight Riders              95
# 3                    Mumbai Indians              86
# 4                   Kings XI Punjab              85
# 5                  Rajasthan Royals              80
# 6               Chennai Super Kings              75
# 7               Sunrisers Hyderabad              45
# 8                   Deccan Chargers              32
# 9                     Pune Warriors              26
# 10                    Gujarat Lions              16
# 11           Rising Pune Supergiant              15
# 12             Kochi Tuskers Kerala               7

# %%
combined_matches_played = pd.concat([matches_playedby_each_team1, matches_playedby_each_team2], axis=0)
total_matches_played_by_team = combined_matches_played.groupby('Team')['matches_played'].sum().reset_index()
total_matches_played_by_team.columns = ['Team', 'totalmatches_played']
total_matches_played_by_team = total_matches_played_by_team.sort_values(by="totalmatches_played",ascending = False)
print(total_matches_played_by_team)
# Out:
#                                Team  totalmatches_played
# 7                    Mumbai Indians                  187
# 11      Royal Challengers Bangalore                  180
# 6             Kolkata Knight Riders                  178
# 2   Delhi Daredevils/Delhi Capitals                  177
# 4                   Kings XI Punjab                  176
# 0               Chennai Super Kings                  164
# 9                  Rajasthan Royals                  147
# 12              Sunrisers Hyderabad                  108
# 1                   Deccan Chargers                   75
# 8                     Pune Warriors                   46
# 3                     Gujarat Lions                   30
# 10           Rising Pune Supergiant                   30
# 5              Kochi Tuskers Kerala                   14

# %%
total_matches_played_by_a_team= total_matches_played_by_team.iloc[0]
total_matches_played_by_a_team
# Out:
# Team                   Mumbai Indians
# totalmatches_played               187
# Name: 7, dtype: object

# %%
total_matches_played_by_a_team_2= total_matches_played_by_team.iloc[1]
total_matches_played_by_a_team_2
# Out:
# Team                   Royal Challengers Bangalore
# totalmatches_played                            180
# Name: 11, dtype: object

# %%
plt.figure(figsize=(12, 6))
bars = plt.bar(total_matches_played_by_team['Team'], total_matches_played_by_team['totalmatches_played'], color='yellow')
plt.xlabel('Team')
plt.ylabel('totalmatches_played')
plt.title('total matches played by each team')
plt.xticks(rotation=45, ha='right')  
plt.tight_layout()
for bar in bars:
    plt.annotate(str(bar.get_height()), (bar.get_x() + bar.get_width() / 2, bar.get_height()), ha='center', va='bottom')
plt.show()

# %%
teams_win = pd.merge(total_matches_played_by_team,mostwon_teams,on='Team')
teams_win
# Out:
#                                Team  totalmatches_played  Wins
# 0                    Mumbai Indians                  187   109
# 1       Royal Challengers Bangalore                  180    84
# 2             Kolkata Knight Riders                  178    92
# 3   Delhi Daredevils/Delhi Capitals                  177    77
# 4                   Kings XI Punjab                  176    82
# 5               Chennai Super Kings                  164   100
# 6                  Rajasthan Royals                  147    75
# 7               Sunrisers Hyderabad                  108    58
# 8                   Deccan Chargers                   75    29
# 9                     Pune Warriors                   46    12
# 10                    Gujarat Lions                   30    13
# 11           Rising Pune Supergiant                   30    15
# 12             Kochi Tuskers Kerala                   14     6

# %%
teams_win['Win_Percentage']= round((teams_win['Wins']/teams_win['totalmatches_played'])*100,2)
teams_win['Win_Percentage'] = teams_win['Win_Percentage'].astype(str) + '%'
teams_win = teams_win.sort_values(by='Win_Percentage',ascending= False)
teams_win
# Out:
#                                Team  totalmatches_played  Wins Win_Percentage
# 5               Chennai Super Kings                  164   100         60.98%
# 0                    Mumbai Indians                  187   109         58.29%
# 7               Sunrisers Hyderabad                  108    58          53.7%
# 2             Kolkata Knight Riders                  178    92         51.69%
# 6                  Rajasthan Royals                  147    75         51.02%
# 11           Rising Pune Supergiant                   30    15          50.0%
# 1       Royal Challengers Bangalore                  180    84         46.67%
# 4                   Kings XI Punjab                  176    82         46.59%
# 3   Delhi Daredevils/Delhi Capitals                  177    77          43.5%
# 10                    Gujarat Lions                   30    13         43.33%
# 12             Kochi Tuskers Kerala                   14     6         42.86%
# ...

# %% [markdown]
# ### Chennai Super Kings has highest win percenatge

# %%
matches_sorted = matches.sort_values(by=['season', 'id'], ascending=[False, False])
season_groups = matches_sorted.groupby('season')
last_match_winners = pd.DataFrame(columns=['season', 'winner'])
for season, group in season_groups:
    last_match = group.iloc[0]
    last_match_winner = {'season': last_match['season'], 'winner': last_match['winner']}
    last_match_winners = pd.concat([last_match_winners, pd.DataFrame([last_match_winner])], ignore_index=True)
print(last_match_winners)
# Out:
#    season                 winner
# 0    2008       Rajasthan Royals
# 1    2009        Deccan Chargers
# 2    2010    Chennai Super Kings
# 3    2011    Chennai Super Kings
# 4    2012  Kolkata Knight Riders
# 5    2013         Mumbai Indians
# 6    2014  Kolkata Knight Riders
# 7    2015         Mumbai Indians
# 8    2016    Sunrisers Hyderabad
# 9    2017         Mumbai Indians
# 10   2018    Chennai Super Kings
# 11   2019         Mumbai Indians

# %%
Most_Titles_Wins = last_match_winners['winner'].value_counts().reset_index()
Most_Titles_Wins.columns = ['winner','Numberof_IPL_Trophy']
Most_Titles_Wins = Most_Titles_Wins.sort_values(by='Numberof_IPL_Trophy',ascending = False)
Most_Titles_Wins
# Out:
#                   winner  Numberof_IPL_Trophy
# 0         Mumbai Indians                    4
# 1    Chennai Super Kings                    3
# 2  Kolkata Knight Riders                    2
# 3       Rajasthan Royals                    1
# 4        Deccan Chargers                    1
# 5    Sunrisers Hyderabad                    1

# %%
max_winby_runs = matches.groupby('winner')['win_by_runs'].max().reset_index()
max_winby_runs.columns = ['winner','win_by_runs']
max_winby_runs = max_winby_runs.sort_values(by='win_by_runs',ascending = False)
max_winby_runs
# Out:
#                              winner  win_by_runs
# 7                    Mumbai Indians          146
# 12      Royal Challengers Bangalore          144
# 6             Kolkata Knight Riders          140
# 13              Sunrisers Hyderabad          118
# 4                   Kings XI Punjab          111
# 10                 Rajasthan Royals          105
# 0               Chennai Super Kings           97
# 2   Delhi Daredevils/Delhi Capitals           97
# 1                   Deccan Chargers           82
# 11           Rising Pune Supergiant           61
# 9                     Pune Warriors           38
# 5              Kochi Tuskers Kerala           17
# 3                     Gujarat Lions            1
# 8                        No Results            0

# %%
winbymaxruns = matches[["team1","team2","winner","win_by_runs"]].sort_values(by="win_by_runs",ascending = False)
winbymaxruns = winbymaxruns.head(10)
winbymaxruns
# Out:
#                            team1                            team2  \
# 43                Mumbai Indians  Delhi Daredevils/Delhi Capitals
# 619  Royal Challengers Bangalore                    Gujarat Lions
# 59         Kolkata Knight Riders      Royal Challengers Bangalore
# 556  Royal Challengers Bangalore                  Kings XI Punjab
# 410  Royal Challengers Bangalore                    Pune Warriors
# 706          Sunrisers Hyderabad      Royal Challengers Bangalore
# 295              Kings XI Punjab      Royal Challengers Bangalore
# 114             Rajasthan Royals  Delhi Daredevils/Delhi Capitals
# 676               Mumbai Indians            Kolkata Knight Riders
# 182               Mumbai Indians  Delhi Daredevils/Delhi Capitals
#
#                           winner  win_by_runs
# 43                Mumbai Indians          146
# 619  Royal Challengers Bangalore          144
# 59         Kolkata Knight Riders          140
# 556  Royal Challengers Bangalore          138
# ...

# %% [markdown]
# ### Mumbai Indians has won a match by maximum runs that is by 146 runs.

# %%
home_wins_mask = matches['team1'] == matches['winner']
home_wins_df = matches[home_wins_mask]
home_wins_count = home_wins_df['team1'].value_counts().reset_index()
home_wins_count.columns = ['Team', 'home_wins']
print(home_wins_count)
# Out:
#                                Team  home_wins
# 0                    Mumbai Indians         58
# 1               Chennai Super Kings         51
# 2                   Kings XI Punjab         38
# 3       Royal Challengers Bangalore         35
# 4             Kolkata Knight Riders         34
# 5               Sunrisers Hyderabad         30
# 6                  Rajasthan Royals         29
# 7   Delhi Daredevils/Delhi Capitals         28
# 8                   Deccan Chargers         18
# 9                     Pune Warriors          6
# 10           Rising Pune Supergiant          5
# 11             Kochi Tuskers Kerala          2
# 12                    Gujarat Lions          1

# %%
home_winpercentage = pd.merge(mostwon_teams,home_wins_count,on = 'Team')
home_winpercentage
# Out:
#                                Team  Wins  home_wins
# 0                    Mumbai Indians   109         58
# 1               Chennai Super Kings   100         51
# 2             Kolkata Knight Riders    92         34
# 3       Royal Challengers Bangalore    84         35
# 4                   Kings XI Punjab    82         38
# 5   Delhi Daredevils/Delhi Capitals    77         28
# 6                  Rajasthan Royals    75         29
# 7               Sunrisers Hyderabad    58         30
# 8                   Deccan Chargers    29         18
# 9            Rising Pune Supergiant    15          5
# 10                    Gujarat Lions    13          1
# 11                    Pune Warriors    12          6
# 12             Kochi Tuskers Kerala     6          2

# %%
home_winpercentage['Home_win_Percentage'] = round((home_winpercentage['home_wins']/home_winpercentage['Wins'])*100,2)
home_winpercentage = home_winpercentage.sort_values(by='Home_win_Percentage',ascending = False)
home_winpercentage['Home_win_Percentage'] = home_winpercentage['Home_win_Percentage'].astype(str) + '%'
home_winpercentage
# Out:
#                                Team  Wins  home_wins Home_win_Percentage
# 8                   Deccan Chargers    29         18              62.07%
# 0                    Mumbai Indians   109         58              53.21%
# 7               Sunrisers Hyderabad    58         30              51.72%
# 1               Chennai Super Kings   100         51               51.0%
# 11                    Pune Warriors    12          6               50.0%
# 4                   Kings XI Punjab    82         38              46.34%
# 3       Royal Challengers Bangalore    84         35              41.67%
# 6                  Rajasthan Royals    75         29              38.67%
# 2             Kolkata Knight Riders    92         34              36.96%
# 5   Delhi Daredevils/Delhi Capitals    77         28              36.36%
# 9            Rising Pune Supergiant    15          5              33.33%
# 12             Kochi Tuskers Kerala     6          2              33.33%
# ...

# %% [markdown]
# ### Mumbai Indians has the most home win percenatge that is 53.21 % , since deccan chargers are not playing anymore

# %% [markdown]
# # Toss Analysis

# %%
tosswin_counts = matches['toss_winner'].value_counts().reset_index()
tosswin_counts.columns = ['Team', 'TossWinCount']
tosswin_counts = tosswin_counts.sort_values(by='TossWinCount', ascending=False)
print(tosswin_counts)
# Out:
#                                Team  TossWinCount
# 0                    Mumbai Indians            98
# 1             Kolkata Knight Riders            92
# 2   Delhi Daredevils/Delhi Capitals            90
# 3               Chennai Super Kings            89
# 4       Royal Challengers Bangalore            81
# 5                   Kings XI Punjab            81
# 6                  Rajasthan Royals            80
# 7               Sunrisers Hyderabad            46
# 8                   Deccan Chargers            43
# 9                     Pune Warriors            20
# 10                    Gujarat Lions            15
# 11           Rising Pune Supergiant            13
# 12             Kochi Tuskers Kerala             8

# %%
plt.figure(figsize=(12, 6))
bars = plt.bar(tosswin_counts['Team'], tosswin_counts['TossWinCount'], color='darkblue')
plt.xlabel('Team')
plt.ylabel('TossWinCount')
plt.title('TossWinCount by Team')
plt.xticks(rotation=45, ha='right')  
plt.tight_layout()
for bar in bars:
    plt.annotate(str(bar.get_height()), (bar.get_x() + bar.get_width() / 2, bar.get_height()), ha='center', va='bottom')
plt.show()

# %%
PercentageTossWin = pd.merge(total_matches_played_by_team,tosswin_counts,on = 'Team')
PercentageTossWin
# Out:
#                                Team  totalmatches_played  TossWinCount
# 0                    Mumbai Indians                  187            98
# 1       Royal Challengers Bangalore                  180            81
# 2             Kolkata Knight Riders                  178            92
# 3   Delhi Daredevils/Delhi Capitals                  177            90
# 4                   Kings XI Punjab                  176            81
# 5               Chennai Super Kings                  164            89
# 6                  Rajasthan Royals                  147            80
# 7               Sunrisers Hyderabad                  108            46
# 8                   Deccan Chargers                   75            43
# 9                     Pune Warriors                   46            20
# 10                    Gujarat Lions                   30            15
# 11           Rising Pune Supergiant                   30            13
# ...

# %% [markdown]
# ### Mumbai Indains has most toss win counts

# %%
PercentageTossWin['TossWinPercentage'] = round((PercentageTossWin['TossWinCount']/PercentageTossWin['totalmatches_played'])*100,2)

PercentageTossWin = PercentageTossWin.sort_values(by='TossWinPercentage',ascending = False)
PercentageTossWin['TossWinPercentage'] = PercentageTossWin['TossWinPercentage'].astype(str) + '%'
PercentageTossWin
# Out:
#                                Team  totalmatches_played  TossWinCount  \
# 8                   Deccan Chargers                   75            43
# 12             Kochi Tuskers Kerala                   14             8
# 6                  Rajasthan Royals                  147            80
# 5               Chennai Super Kings                  164            89
# 0                    Mumbai Indians                  187            98
# 2             Kolkata Knight Riders                  178            92
# 3   Delhi Daredevils/Delhi Capitals                  177            90
# 10                    Gujarat Lions                   30            15
# 4                   Kings XI Punjab                  176            81
# 1       Royal Challengers Bangalore                  180            81
# 9                     Pune Warriors                   46            20
# 11           Rising Pune Supergiant                   30            13
# ...

# %%
tossdecision = matches["toss_decision"].value_counts().reset_index()
tossdecision.columns = ["TossDecision","Count"]
tossdecision = tossdecision.sort_values(by="Count",ascending = False)
tossdecision
# Out:
#   TossDecision  Count
# 0        field    463
# 1          bat    293

# %%
same_tosswinnerandwinner = matches[matches["toss_winner"] == matches["winner"]]
same_tosswinnerandwinner
# Out:
#         id  season           city        date  \
# 1        2    2017           Pune  2017-04-06
# 2        3    2017         Rajkot  2017-04-07
# 3        4    2017         Indore  2017-04-08
# 4        5    2017      Bangalore  2017-04-08
# 5        6    2017      Hyderabad  2017-04-09
# ..     ...     ...            ...         ...
# 750  11346    2019         Mohali    05/05/19
# 751  11347    2019         Mumbai    05/05/19
# 753  11413    2019  Visakhapatnam    08/05/19
# 754  11414    2019  Visakhapatnam    10/05/19
# 755  11415    2019      Hyderabad    12/05/19
#
#                                team1                            team2  \
# 1                     Mumbai Indians           Rising Pune Supergiant
# 2                      Gujarat Lions            Kolkata Knight Riders
# 3             Rising Pune Supergiant                  Kings XI Punjab
# 4        Royal Challengers Bangalore  Delhi Daredevils/Delhi Capitals
# ...

# %%
len(same_tosswinnerandwinner)
# Out:
# 393

# %%
matchwithresult = matches[matches['winner'] != 'No Results']
matchwithresult
# Out:
#         id  season           city        date  \
# 0        1    2017      Hyderabad  2017-04-05
# 1        2    2017           Pune  2017-04-06
# 2        3    2017         Rajkot  2017-04-07
# 3        4    2017         Indore  2017-04-08
# 4        5    2017      Bangalore  2017-04-08
# ..     ...     ...            ...         ...
# 751  11347    2019         Mumbai    05/05/19
# 752  11412    2019        Chennai    07/05/19
# 753  11413    2019  Visakhapatnam    08/05/19
# 754  11414    2019  Visakhapatnam    10/05/19
# 755  11415    2019      Hyderabad    12/05/19
#
#                                team1                            team2  \
# 0                Sunrisers Hyderabad      Royal Challengers Bangalore
# 1                     Mumbai Indians           Rising Pune Supergiant
# 2                      Gujarat Lions            Kolkata Knight Riders
# 3             Rising Pune Supergiant                  Kings XI Punjab
# ...

# %%
len(matchwithresult)
# Out:
# 752

# %%
import math

# %%
percetagewonbytosswinner = round((len(same_tosswinnerandwinner)/len(matchwithresult))*100)
print(percetagewonbytosswinner," %")
# Out:
# 52  %

# %%
TossWin_firstfield_Winner = matches[(matches["toss_decision"] == "field") & (matches["toss_winner"] == matches["winner"])]
TossWin_firstfield_Winner
# Out:
#         id  season           city        date  \
# 1        2    2017           Pune  2017-04-06
# 2        3    2017         Rajkot  2017-04-07
# 3        4    2017         Indore  2017-04-08
# 5        6    2017      Hyderabad  2017-04-09
# 6        7    2017         Mumbai  2017-04-09
# ..     ...     ...            ...         ...
# 749  11345    2019      Bengaluru    04/05/19
# 750  11346    2019         Mohali    05/05/19
# 751  11347    2019         Mumbai    05/05/19
# 753  11413    2019  Visakhapatnam    08/05/19
# 754  11414    2019  Visakhapatnam    10/05/19
#
#                                team1                            team2  \
# 1                     Mumbai Indians           Rising Pune Supergiant
# 2                      Gujarat Lions            Kolkata Knight Riders
# 3             Rising Pune Supergiant                  Kings XI Punjab
# 5                      Gujarat Lions              Sunrisers Hyderabad
# ...

# %%
TossWin_firstfield_Winner = matches[(matches["toss_decision"] == "field") & (matches["toss_winner"] == matches["winner"])]
TossWin_firstfield_Winner
# Out:
#         id  season           city        date  \
# 1        2    2017           Pune  2017-04-06
# 2        3    2017         Rajkot  2017-04-07
# 3        4    2017         Indore  2017-04-08
# 5        6    2017      Hyderabad  2017-04-09
# 6        7    2017         Mumbai  2017-04-09
# ..     ...     ...            ...         ...
# 749  11345    2019      Bengaluru    04/05/19
# 750  11346    2019         Mohali    05/05/19
# 751  11347    2019         Mumbai    05/05/19
# 753  11413    2019  Visakhapatnam    08/05/19
# 754  11414    2019  Visakhapatnam    10/05/19
#
#                                team1                            team2  \
# 1                     Mumbai Indians           Rising Pune Supergiant
# 2                      Gujarat Lions            Kolkata Knight Riders
# 3             Rising Pune Supergiant                  Kings XI Punjab
# 5                      Gujarat Lions              Sunrisers Hyderabad
# ...

# %%
len(TossWin_firstfield_Winner)
# Out:
# 259

# %%
percetageTossWin_firstfield_Winner = round((len(TossWin_firstfield_Winner)/len(matchwithresult))*100)
print(percetageTossWin_firstfield_Winner," %")
# Out:
# 34  %

# %%
TossWin_firstbat_Winner = matches[(matches["toss_decision"] == "bat") & (matches["toss_winner"] == matches["winner"])]
TossWin_firstbat_Winner
# Out:
#         id  season       city        date                            team1  \
# 4        5    2017  Bangalore  2017-04-08      Royal Challengers Bangalore
# 14      15    2017      Delhi  2017-04-15  Delhi Daredevils/Delhi Capitals
# 20      21    2017  Hyderabad  2017-04-19              Sunrisers Hyderabad
# 50      51    2017      Delhi  2017-05-12  Delhi Daredevils/Delhi Capitals
# 54      55    2017      Delhi  2017-05-14      Royal Challengers Bangalore
# ..     ...     ...        ...         ...                              ...
# 713  11309    2019    Chennai    06/04/19              Chennai Super Kings
# 729  11325    2019      Delhi    18/04/19                   Mumbai Indians
# 741  11337    2019      Delhi    28/04/19  Delhi Daredevils/Delhi Capitals
# 746  11342    2019     Mumbai    02/05/19                   Mumbai Indians
# 755  11415    2019  Hyderabad    12/05/19                   Mumbai Indians
#
# ...

# %%
len(TossWin_firstbat_Winner)
# Out:
# 134

# %%
percetageTossWin_firstbat_Winner = round((len(TossWin_firstbat_Winner)/len(matchwithresult))*100)
print(percetageTossWin_firstbat_Winner," %")
# Out:
# 18  %

# %%
Tosslost_firstbat_Winner = matches[(matches["toss_decision"] == "bat") & (matches["toss_winner"] != matches["winner"])]
Tosslost_firstbat_Winner
# Out:
#         id  season       city        date                            team1  \
# 7        8    2017     Indore  2017-04-10      Royal Challengers Bangalore
# 17      18    2017      Delhi  2017-04-17  Delhi Daredevils/Delhi Capitals
# 33      34    2017     Rajkot  2017-04-29                    Gujarat Lions
# 36      37    2017     Mumbai  2017-05-01      Royal Challengers Bangalore
# 46      47    2017  Hyderabad  2017-05-08                   Mumbai Indians
# ..     ...     ...        ...         ...                              ...
# 700  11141    2019      Delhi    26/03/19  Delhi Daredevils/Delhi Capitals
# 703  11144    2019  Hyderabad    29/03/19                 Rajasthan Royals
# 728  11324    2019  Hyderabad    17/04/19              Chennai Super Kings
# 748  11344    2019      Delhi    04/05/19                 Rajasthan Royals
# 752  11412    2019    Chennai    07/05/19              Chennai Super Kings
#
# ...

# %%
len(Tosslost_firstbat_Winner)
# Out:
# 159

# %%
percetageTosslost_firstbat_Winner = round((len(Tosslost_firstbat_Winner)/len(matchwithresult))*100)
print(percetageTosslost_firstbat_Winner," %")
# Out:
# 21  %

# %%
Tosslost_firstfield_Winner = matches[(matches["toss_decision"] == "field") & (matches["toss_winner"] != matches["winner"])]
Tosslost_firstfield_Winner
# Out:
#         id  season       city        date                            team1  \
# 0        1    2017  Hyderabad  2017-04-05              Sunrisers Hyderabad
# 8        9    2017       Pune  2017-04-11  Delhi Daredevils/Delhi Capitals
# 13      14    2017    Kolkata  2017-04-15            Kolkata Knight Riders
# 16      17    2017  Bangalore  2017-04-16           Rising Pune Supergiant
# 18      19    2017  Hyderabad  2017-04-17              Sunrisers Hyderabad
# ..     ...     ...        ...         ...                              ...
# 739  11335    2019    Chennai    26/04/19                   Mumbai Indians
# 742  11338    2019    Kolkata    28/04/19            Kolkata Knight Riders
# 743  11339    2019  Hyderabad    29/04/19              Sunrisers Hyderabad
# 744  11340    2019  Bengaluru    30/04/19      Royal Challengers Bangalore
# 745  11341    2019    Chennai    01/05/19              Chennai Super Kings
#
# ...

# %%
len(Tosslost_firstfield_Winner)
# Out:
# 204

# %%
percetageTosslost_firstfield_Winner = round((len(Tosslost_firstfield_Winner)/len(matchwithresult))*100)
print(percetageTosslost_firstfield_Winner," %")
# Out:
# 27  %

# %%
import matplotlib.pyplot as plt
categories = ['TossWin_firstfield_Winner', 'TossWin_firstbat_Winner', 'Tosslost_firstbat_Winner', 'Tosslost_firstfield_Winner']
counts = [34, 18, 21, 27]  # Replace with the actual numerical percentages (without % symbols)
plt.figure(figsize=(5, 5))
plt.pie(counts, labels=categories, autopct='%1.1f%%', startangle=140)
plt.subplots_adjust(top=0.85)  # Add more space at the top
plt.title('Combined Pie Chart for Toss Outcomes', y=1.08)  # Adjust the title's position
plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
plt.show()

# %%
teamfieldedfirst_wonmatch = round(((len(Tosslost_firstfield_Winner)+len(TossWin_firstfield_Winner))/len(matches))*100,2)
print(teamfieldedfirst_wonmatch,' %')
# Out:
# 61.24  %

# %%
teambattedfirst_wonmatch = round(((len(Tosslost_firstbat_Winner)+len(TossWin_firstbat_Winner))/len(matches))*100,2)
print(teambattedfirst_wonmatch ,' %')
# Out:
# 38.76  %

# %%
import matplotlib.pyplot as plt

categories = ['teamfieldedfirst_wonmatch', 'teambattedfirst_wonmatch']
counts = [61.24, 38.76]  # Replace with the actual numerical percentages (without % symbols)

plt.figure(figsize=(5, 5))
plt.pie(counts, labels=categories, autopct='%1.1f%%', startangle=140)
plt.subplots_adjust(top=0.85)  # Add more space at the top
plt.title('Combined Pie Chart for Toss Outcomes', y=1.08)  # Adjust the title's position
plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
plt.show()

# %% [markdown]
# ### Team which field first has highest success rate

# %% [markdown]
# # Batting Analysis

# %%
TopBatsman = deliveries.groupby('batsman')['batsman_runs'].sum().reset_index()
TopBatsman.columns = ["batsman","total_runs"]
TopBatsman = TopBatsman.sort_values(by ="total_runs",ascending = False)
TopBatsman
# Out:
#          batsman  total_runs
# 486      V Kohli        5434
# 428     SK Raina        5415
# 367    RG Sharma        4914
# 112    DA Warner        4741
# 392     S Dhawan        4632
# ..           ...         ...
# 172    IC Pandey           0
# 182      J Denly           0
# 326        P Raj           0
# 463  Sunny Gupta           0
# 235     L Ablish           0
#
# [516 rows x 2 columns]

# %%
top_batters = TopBatsman.head(10)
top_batters
# Out:
#             batsman  total_runs
# 486         V Kohli        5434
# 428        SK Raina        5415
# 367       RG Sharma        4914
# 112       DA Warner        4741
# 392        S Dhawan        4632
# 92         CH Gayle        4560
# 290        MS Dhoni        4477
# 384      RV Uthappa        4446
# 26   AB de Villiers        4428
# 147       G Gambhir        4223

# %%
plt.figure(figsize=(12, 6))
bars = plt.bar(top_batters['batsman'],top_batters['total_runs'], color='darkorange')
plt.xlabel('batsman')
plt.ylabel('total_runs')
plt.title('Top Batsman by Total Runs')
plt.xticks(rotation=45, ha='right')  # Rotate x-axis labels and align them to the right
plt.tight_layout()

# Annotate the bars with win counts
for bar in bars:
    plt.annotate(str(bar.get_height()), (bar.get_x() + bar.get_width() / 2, bar.get_height()), ha='center', va='bottom')

# Display the bar chart
plt.show()

# %% [markdown]
# ### Virat Kohli has scored most runs in IPL that is 5434

# %%
balls_played_by_batsman = deliveries.groupby('batsman')['ball'].count().reset_index()
balls_played_by_batsman.columns = ["batsman","balls_played"]
balls_played_by_batsman = balls_played_by_batsman.sort_values(by="balls_played",ascending = False)
balls_played_by_batsman
# Out:
#          batsman  balls_played
# 486      V Kohli          4211
# 428     SK Raina          4044
# 367    RG Sharma          3816
# 392     S Dhawan          3776
# 147    G Gambhir          3524
# ..           ...           ...
# 326        P Raj             1
# 463  Sunny Gupta             1
# 242  LH Ferguson             1
# 87       C Nanda             1
# 398    S Kaushik             1
#
# [516 rows x 2 columns]

# %%
merged_df = pd.merge(TopBatsman,balls_played_by_batsman,on ="batsman").head(120)
merged_df
# Out:
#         batsman  total_runs  balls_played
# 0       V Kohli        5434          4211
# 1      SK Raina        5415          4044
# 2     RG Sharma        4914          3816
# 3     DA Warner        4741          3398
# 4      S Dhawan        4632          3776
# ..          ...         ...           ...
# 115    JR Hopes         417           314
# 116     SN Khan         416           291
# 117     J Botha         409           364
# 118   LR Shukla         405           358
# 119  AL Menaria         401           367
#
# [120 rows x 3 columns]

# %%
merged_df['Strike_Rate'] = round((merged_df['total_runs']/merged_df['balls_played'])*100)
merged_df['Strike_Rate'] = merged_df['Strike_Rate'].astype(str) + '%'
merged_df = merged_df.sort_values(by='Strike_Rate',ascending = False).head(20)
print(merged_df)
# Out:
#             batsman  total_runs  balls_played Strike_Rate
# 48       AD Russell        1445           803      180.0%
# 81        SP Narine         803           481      167.0%
# 37          RR Pant        1792          1104      162.0%
# 109      J Bairstow         468           293      160.0%
# 51       GJ Maxwell        1403           902      156.0%
# 103       CH Morris         520           339      153.0%
# 61        HH Pandya        1118           736      152.0%
# 50       JC Buttler        1431           954      150.0%
# 8    AB de Villiers        4428          2977      149.0%
# 20         V Sehwag        2728          1833      149.0%
# 5          CH Gayle        4560          3131      146.0%
# 75        KH Pandya         915           635      144.0%
# 116         SN Khan         416           291      143.0%
# 93           P Shaw         616           435      142.0%
# 18       KA Pollard        2784          1964      142.0%
# ...

# %% [markdown]
# ### AD Russell has the highest strike rate that is 180.0%

# %%
Player_dismissals = deliveries.groupby('batsman')['player_dismissed'].count().reset_index()
Player_dismissals.columns = ['batsman','Nooftimes_dismissed']
Player_dismissals = Player_dismissals.sort_values(by="Nooftimes_dismissed",ascending = False)
Player_dismissals
# Out:
#            batsman  Nooftimes_dismissed
# 367      RG Sharma                  162
# 428       SK Raina                  161
# 384     RV Uthappa                  157
# 486        V Kohli                  152
# 218     KD Karthik                  140
# ..             ...                  ...
# 55    Abdur Razzak                    0
# 326          P Raj                    0
# 212     K Upadhyay                    0
# 48        AR Bawne                    0
# 113  DAJ Bracewell                    0
#
# [516 rows x 2 columns]

# %%
merged_df2 = pd.merge(TopBatsman,Player_dismissals,on ="batsman").head(120)
merged_df2
# Out:
#         batsman  total_runs  Nooftimes_dismissed
# 0       V Kohli        5434                  152
# 1      SK Raina        5415                  161
# 2     RG Sharma        4914                  162
# 3     DA Warner        4741                  114
# 4      S Dhawan        4632                  137
# ..          ...         ...                  ...
# 115    JR Hopes         417                   17
# 116     SN Khan         416                   18
# 117     J Botha         409                   22
# 118   LR Shukla         405                   29
# 119  AL Menaria         401                   22
#
# [120 rows x 3 columns]

# %%
merged_df2['Batting_Average'] = round((merged_df2['total_runs']/merged_df2['Nooftimes_dismissed']),2)
merged_df2 = merged_df2.sort_values(by = 'Batting_Average',ascending = False).head(20)
merged_df2
# Out:
#             batsman  total_runs  Nooftimes_dismissed  Batting_Average
# 109      J Bairstow         468                    8            58.50
# 97          HM Amla         577                   13            44.38
# 8    AB de Villiers        4428                  104            42.58
# 30        JP Duminy        2041                   49            41.65
# 3         DA Warner        4741                  114            41.59
# 5          CH Gayle        4560                  110            41.45
# 31         KL Rahul        2013                   49            41.08
# 65      LMP Simmons        1079                   27            39.96
# 62        ML Hayden        1107                   28            39.54
# 106         OA Shah         506                   13            38.92
# 55    KS Williamson        1319                   34            38.79
# 22         SE Marsh        2489                   65            38.29
# ...

# %% [markdown]
# ### J Bairstow has the highest batting average 58.50

# %%
HIS = deliveries.groupby(['match_id','batsman'])['batsman_runs'].sum().reset_index()
HIS.columns = ['match_id','batsman','batsman_runs']
HIS= HIS.sort_values(by = 'batsman_runs', ascending = False)
HIS
# Out:
#        match_id         batsman  batsman_runs
# 6200        411        CH Gayle           175
# 900          60     BB McCullum           158
# 8426        562  AB de Villiers           133
# 10149      7935         RR Pant           130
# 9257        620  AB de Villiers           129
# ...         ...             ...           ...
# 6845        455       DH Yagnik             0
# 404          27         V Kohli             0
# 1804        119        MM Patel             0
# 1802        119     LRPL Taylor             0
# 3090        203        FY Fazal             0
#
# [11294 rows x 3 columns]

# %%
HIS.head(10)
# Out:
#        match_id         batsman  batsman_runs
# 6200        411        CH Gayle           175
# 900          60     BB McCullum           158
# 8426        562  AB de Villiers           133
# 10149      7935         RR Pant           130
# 9257        620  AB de Villiers           129
# 5585        372        CH Gayle           128
# 3135        206         M Vijay           127
# 529          36       DA Warner           126
# 7752        516        V Sehwag           122
# 10417      7953       SR Watson           121

# %%
match_HIS_df = matches[['id','team1','team2','winner']]
match_HIS_df
# Out:
#         id                            team1                            team2  \
# 0        1              Sunrisers Hyderabad      Royal Challengers Bangalore
# 1        2                   Mumbai Indians           Rising Pune Supergiant
# 2        3                    Gujarat Lions            Kolkata Knight Riders
# 3        4           Rising Pune Supergiant                  Kings XI Punjab
# 4        5      Royal Challengers Bangalore  Delhi Daredevils/Delhi Capitals
# ..     ...                              ...                              ...
# 751  11347            Kolkata Knight Riders                   Mumbai Indians
# 752  11412              Chennai Super Kings                   Mumbai Indians
# 753  11413              Sunrisers Hyderabad  Delhi Daredevils/Delhi Capitals
# 754  11414  Delhi Daredevils/Delhi Capitals              Chennai Super Kings
# 755  11415                   Mumbai Indians              Chennai Super Kings
#
#                               winner
# ...

# %%
Highest_Individual_Score = pd.merge(HIS,match_HIS_df,left_on='match_id', right_on='id')
Highest_Individual_Score = Highest_Individual_Score.drop(columns=['id'])
Highest_Individual_Score
# Out:
#        match_id          batsman  batsman_runs  \
# 0           411         CH Gayle           175
# 1           411        SPD Smith            41
# 2           411       TM Dilshan            33
# 3           411   AB de Villiers            31
# 4           411         MR Marsh            24
# ...         ...              ...           ...
# 11289       301        DA Warner            19
# 11290       301        CA Ingram            13
# 11291       301          MS Wade            11
# 11292       301          NV Ojha             8
# 11293       301  Y Venugopal Rao             0
#
#                                  team1          team2  \
# 0          Royal Challengers Bangalore  Pune Warriors
# 1          Royal Challengers Bangalore  Pune Warriors
# 2          Royal Challengers Bangalore  Pune Warriors
# 3          Royal Challengers Bangalore  Pune Warriors
# 4          Royal Challengers Bangalore  Pune Warriors
# ...                                ...            ...
# ...

# %% [markdown]
# ### CH Gayle has scored highest individual score that is 175

# %%
HIS_Filtered = Highest_Individual_Score['batsman_runs'] >= 100
HIS_Centuries = Highest_Individual_Score[HIS_Filtered]
HIS_Centuries
# Out:
#      match_id         batsman  batsman_runs                            team1  \
# 0         411        CH Gayle           175      Royal Challengers Bangalore
# 17         60     BB McCullum           158            Kolkata Knight Riders
# 33        562  AB de Villiers           133      Royal Challengers Bangalore
# 45       7935         RR Pant           130  Delhi Daredevils/Delhi Capitals
# 54        620  AB de Villiers           129      Royal Challengers Bangalore
# ..        ...             ...           ...                              ...
# 737     11326         V Kohli           100      Royal Challengers Bangalore
# 748       176       YK Pathan           100                   Mumbai Indians
# 764       425        SK Raina           100              Chennai Super Kings
# 778       505     LMP Simmons           100                  Kings XI Punjab
# 793       521     BB McCullum           100              Chennai Super Kings
#
# ...

# %%
HIS_Centuries_gayle = HIS_Centuries[HIS_Centuries['batsman'] == 'CH Gayle']
HIS_Centuries_gayle
# Out:
#      match_id   batsman  batsman_runs                        team1  \
# 0         411  CH Gayle           175  Royal Challengers Bangalore
# 69        372  CH Gayle           128  Royal Challengers Bangalore
# 175       557  CH Gayle           117  Royal Challengers Bangalore
# 304      7909  CH Gayle           111              Kings XI Punjab
# 423       280  CH Gayle           107  Royal Challengers Bangalore
# 468     11319  CH Gayle           105              Kings XI Punjab
# 615       258  CH Gayle           102        Kolkata Knight Riders
#
#                                team2                       winner
# 0                      Pune Warriors  Royal Challengers Bangalore
# 69   Delhi Daredevils/Delhi Capitals  Royal Challengers Bangalore
# 175                  Kings XI Punjab  Royal Challengers Bangalore
# 304              Sunrisers Hyderabad              Kings XI Punjab
# 423                  Kings XI Punjab  Royal Challengers Bangalore
# ...

# %%
Most_Centuries_by_Player = HIS_Centuries['batsman'].value_counts().reset_index()
Most_Centuries_by_Player.columns = ['batsman','Century_Count']
Most_Centuries_by_Player = Most_Centuries_by_Player.sort_values(by = 'Century_Count', ascending = False).head(10)
Most_Centuries_by_Player
# Out:
#            batsman  Century_Count
# 0         CH Gayle              7
# 1          V Kohli              5
# 2        DA Warner              4
# 3        SR Watson              4
# 4   AB de Villiers              3
# 9      BB McCullum              2
# 11        V Sehwag              2
# 10       SV Samson              2
# 12         M Vijay              2
# 8     AC Gilchrist              2

# %% [markdown]
# ### CH Gayle has record of most centuries by a player in ipl that is 7

# %%
len(HIS_Centuries)
# Out:
# 62

# %%
HIS_Centuries_Won = HIS_Centuries['team1'] == HIS_Centuries['winner']
HIS_Centuries_Won_Team = HIS_Centuries[HIS_Centuries_Won]
HIS_Centuries_Won_Team
# Out:
#      match_id         batsman  batsman_runs                            team1  \
# 0         411        CH Gayle           175      Royal Challengers Bangalore
# 17         60     BB McCullum           158            Kolkata Knight Riders
# 33        562  AB de Villiers           133      Royal Challengers Bangalore
# 54        620  AB de Villiers           129      Royal Challengers Bangalore
# 55        620         V Kohli           109      Royal Challengers Bangalore
# 69        372        CH Gayle           128      Royal Challengers Bangalore
# 82        206         M Vijay           127              Chennai Super Kings
# 95         36       DA Warner           126              Sunrisers Hyderabad
# 107       516        V Sehwag           122                  Kings XI Punjab
# 175       557        CH Gayle           117      Royal Challengers Bangalore
# 191        61      MEK Hussey           116              Chennai Super Kings
# ...

# %%
len(HIS_Centuries_Won_Team)
# Out:
# 32

# %%
HIS_won_percentage = round(((len(HIS_Centuries_Won_Team)/len(HIS_Centuries))*100),2)
print(HIS_won_percentage,' %')
# Out:
# 51.61  %

# %%
HIS_Filtered_Fifty = (Highest_Individual_Score['batsman_runs'] >= 50) & (Highest_Individual_Score['batsman_runs'] <100)
HIS_Fifties = Highest_Individual_Score[HIS_Filtered_Fifty]
HIS_Fifties
# Out:
#       match_id         batsman  batsman_runs                            team1  \
# 34         562         V Kohli            82      Royal Challengers Bangalore
# 35         562     LMP Simmons            68      Royal Challengers Bangalore
# 46        7935        S Dhawan            94  Delhi Daredevils/Delhi Capitals
# 47        7935   KS Williamson            83  Delhi Daredevils/Delhi Capitals
# 70         372         V Kohli            73      Royal Challengers Bangalore
# ...        ...             ...           ...                              ...
# 9205       308         RE Levi            50              Chennai Super Kings
# 9221       150  AB de Villiers            50                   Mumbai Indians
# 9236      7945       AT Rayudu            50  Delhi Daredevils/Delhi Capitals
# 9251        35      MJ Guptill            50  Delhi Daredevils/Delhi Capitals
# 9264       252        SK Raina            50              Chennai Super Kings
#
# ...

# %%
HIS_Fifties_by_player = HIS_Fifties['batsman'].value_counts().reset_index()
HIS_Fifties_by_player.columns = ['batsman','Fifties_Count']
HIS_Fifties_by_player = HIS_Fifties_by_player.sort_values(by = 'Fifties_Count',ascending = False).head(20)
HIS_Fifties_by_player
# Out:
#            batsman  Fifties_Count
# 0        DA Warner             44
# 2          V Kohli             38
# 1         SK Raina             38
# 3         S Dhawan             37
# 5        RG Sharma             36
# 4        G Gambhir             36
# 6   AB de Villiers             34
# 7         CH Gayle             28
# 8        AM Rahane             27
# 9       RV Uthappa             24
# 10        MS Dhoni             23
# 11        SE Marsh             20
# 12       SR Watson             19
# 13       AT Rayudu             19
# 14       JH Kallis             17
# 15      KD Karthik             17
# 16        DR Smith             17
# 17        V Sehwag             16
# 19       MK Pandey             15
# 20      MEK Hussey             15

# %% [markdown]
# ### DA Warner has scored most fifties in ipl that is 44

# %%
boundary_deliveries = deliveries[(deliveries['batsman_runs'] == 4) | (deliveries['batsman_runs'] == 6)]
Boundaries_by_Player = boundary_deliveries.groupby('batsman')['batsman_runs'].sum().reset_index()
Boundaries_by_Player.columns = ['batsman','boundary_runs']
Boundaries_by_Player = Boundaries_by_Player.sort_values(by = 'boundary_runs', ascending = False)
Boundaries_by_Player
# Out:
#            batsman  boundary_runs
# 79        CH Gayle           3466
# 353       SK Raina           3150
# 401        V Kohli           3074
# 93       DA Warner           2922
# 305      RG Sharma           2888
# ..             ...            ...
# 381  Shivam Sharma              4
# 155       J Theron              4
# 283       PV Tambe              4
# 280     PJ Sangwan              4
# 109      DNT Zoysa              4
#
# [424 rows x 2 columns]

# %%
six_deliveries = deliveries[deliveries['batsman_runs'] == 6]
sixes_by_Player = six_deliveries.groupby('batsman')['batsman_runs'].count().reset_index()
sixes_by_Player.columns = ['batsman','sixes_count']
sixes_by_Player = sixes_by_Player.sort_values(by = 'sixes_count', ascending = False).head(10)
sixes_by_Player
# Out:
#             batsman  sixes_count
# 59         CH Gayle          327
# 12   AB de Villiers          214
# 193        MS Dhoni          207
# 278        SK Raina          195
# 240       RG Sharma          194
# 318         V Kohli          191
# 71        DA Warner          181
# 291       SR Watson          177
# 139      KA Pollard          175
# 332       YK Pathan          161

# %%
four_deliveries = deliveries[deliveries['batsman_runs'] == 4]
fours_by_Player = four_deliveries.groupby('batsman')['batsman_runs'].count().reset_index()
fours_by_Player.columns = ['batsman','fours_count']
fours_by_Player = fours_by_Player.sort_values(by = 'fours_count', ascending = False).head(10)
fours_by_Player
# Out:
#         batsman  fours_count
# 317    S Dhawan          526
# 343    SK Raina          495
# 120   G Gambhir          492
# 387     V Kohli          482
# 89    DA Warner          459
# 310  RV Uthappa          436
# 295   RG Sharma          431
# 36    AM Rahane          405
# 77     CH Gayle          376
# 265    PA Patel          366

# %%
Boundaries_Percentage = pd.merge(TopBatsman,Boundaries_by_Player,on = 'batsman')
Boundaries_Percentage = Boundaries_Percentage.sort_values(by = 'boundary_runs',ascending = False).head(20)
Boundaries_Percentage['boundary_percentage'] = round((Boundaries_Percentage['boundary_runs']/Boundaries_Percentage['total_runs'])*100,2)
Boundaries_Percentage['boundary_percentage'] = Boundaries_Percentage['boundary_percentage'].astype(str) + '%'
Boundaries_Percentage = Boundaries_Percentage.sort_values(by = 'boundary_percentage',ascending = False )
Boundaries_Percentage
# Out:
#            batsman  total_runs  boundary_runs boundary_percentage
# 5         CH Gayle        4560           3466              76.01%
# 20        V Sehwag        2728           1972              72.29%
# 12       SR Watson        3614           2438              67.46%
# 15     BB McCullum        2893           1946              67.27%
# 19    Yuvraj Singh        2765           1766              63.87%
# 18      KA Pollard        2784           1778              63.86%
# 14       YK Pathan        3241           2022              62.39%
# 3        DA Warner        4741           2922              61.63%
# 8   AB de Villiers        4428           2712              61.25%
# 16        PA Patel        2874           1758              61.17%
# 7       RV Uthappa        4446           2680              60.28%
# 2        RG Sharma        4914           2888              58.77%
# 1         SK Raina        5415           3150              58.17%
# ...

# %% [markdown]
# ### CH Gayle has highest boundary percentage 76.01%

# %% [markdown]
# # Bowling and Fielding Analysis

# %%
Topdismissal_kind= deliveries.groupby('dismissal_kind')['player_dismissed'].count().reset_index()
Topdismissal_kind.columns = ["dismissal_kind","total_dismissals"]
Topdismissal_kind = Topdismissal_kind.sort_values(by="total_dismissals",ascending = False).head(10)
Topdismissal_kind
# Out:
#           dismissal_kind  total_dismissals
# 1                 caught              5348
# 0                 bowled              1581
# 7                run out               852
# 4                    lbw               540
# 8                stumped               278
# 2      caught and bowled               211
# 6           retired hurt                12
# 3             hit wicket                10
# 5  obstructing the field                 2

# %%
plt.figure(figsize=(12, 6))
bars = plt.bar(Topdismissal_kind['dismissal_kind'],Topdismissal_kind['total_dismissals'], color='red')
plt.xlabel('dismissal_kind')
plt.ylabel('total_dismissals')
plt.title('dismissal kind vs total dismissals')
plt.xticks(rotation=45, ha='right')  # Rotate x-axis labels and align them to the right
plt.tight_layout()

# Annotate the bars with win counts
for bar in bars:
    plt.annotate(str(bar.get_height()), (bar.get_x() + bar.get_width() / 2, bar.get_height()), ha='center', va='bottom')

# Display the bar chart
plt.show()

# %%
deliveries[deliveries["dismissal_kind"]=="hit wicket"]
# Out:
#         match_id  inning                 batting_team            bowling_team  \
# 9261          40       1        Kolkata Knight Riders  Rising Pune Supergiant
# 16220         69       2               Mumbai Indians         Kings XI Punjab
# 21893         94       1  Royal Challengers Bangalore         Kings XI Punjab
# 31891        137       2             Rajasthan Royals     Chennai Super Kings
# 73687        313       1          Chennai Super Kings         Deccan Chargers
# 86635        367       1  Royal Challengers Bangalore          Mumbai Indians
# 145035       613       1          Sunrisers Hyderabad          Mumbai Indians
# 146217       618       1          Sunrisers Hyderabad        Delhi Daredevils
# 147152       622       2          Sunrisers Hyderabad         Kings XI Punjab
# 175184     11334       2             Rajasthan Royals   Kolkata Knight Riders
#
#         over  ball        batsman    non_striker             bowler  \
# ...

# %%
deliveries[deliveries["dismissal_kind"]=="obstructing the field"]
# Out:
#         match_id  inning           batting_team         bowling_team  over  \
# 105613       445       2  Kolkata Knight Riders        Pune Warriors    18
# 178589     11413       2         Delhi Capitals  Sunrisers Hyderabad    20
#
#         ball    batsman non_striker      bowler  is_super_over  ...  bye_runs  \
# 105613     5  YK Pathan      DB Das  WD Parnell              0  ...         0
# 178589     5   A Mishra      K Paul     K Ahmed              0  ...         0
#
#         legbye_runs  noball_runs  penalty_runs  batsman_runs  extra_runs  \
# 105613            0            0             0             0           0
# 178589            0            0             0             0           0
#
#         total_runs  player_dismissed         dismissal_kind fielder
# 105613           0         YK Pathan  obstructing the field     NaN
# 178589           0          A Mishra  obstructing the field     NaN
#
# [2 rows x 21 columns]

# %%
deliveries[deliveries["dismissal_kind"]=="retired hurt"]
# Out:
#         match_id  inning             batting_team  \
# 8712          37       2           Mumbai Indians
# 14576         63       1           Mumbai Indians
# 41338        176       1           Mumbai Indians
# 43622        186       1          Deccan Chargers
# 72649        308       2           Mumbai Indians
# 105334       444       2           Mumbai Indians
# 112066       473       1           Mumbai Indians
# 124697       526       1           Mumbai Indians
# 139979       592       2  Rising Pune Supergiants
# 154107      7909       2      Sunrisers Hyderabad
# 157333      7922       2    Kolkata Knight Riders
# 165453     11139       2           Mumbai Indians
#
#                        bowling_team  over  ball          batsman  \
# 8712    Royal Challengers Bangalore    14     3        KH Pandya
# 14576   Royal Challengers Bangalore     4     4      DJ Thornely
# 41338              Rajasthan Royals    20     5  Harbhajan Singh
# ...

# %%
deliveries[deliveries["dismissal_kind"]=="run out"]
# Out:
#         match_id  inning                 batting_team            bowling_team  \
# 199            1       2  Royal Challengers Bangalore     Sunrisers Hyderabad
# 247            1       2  Royal Challengers Bangalore     Sunrisers Hyderabad
# 371            2       1               Mumbai Indians  Rising Pune Supergiant
# 1063           5       1  Royal Challengers Bangalore        Delhi Daredevils
# 1313           6       1                Gujarat Lions     Sunrisers Hyderabad
# ...          ...     ...                          ...                     ...
# 177016     11343       1              Kings XI Punjab   Kolkata Knight Riders
# 177195     11344       1             Rajasthan Royals          Delhi Capitals
# 178951     11415       1               Mumbai Indians     Chennai Super Kings
# 179033     11415       2          Chennai Super Kings          Mumbai Indians
# 179075     11415       2          Chennai Super Kings          Mumbai Indians
#
# ...

# %%
dismissals_to_exclude = ['run out', 'obstructing the field','retired hurt']

filtered_deliveries = deliveries[~deliveries['dismissal_kind'].isin(dismissals_to_exclude)]

TopBowlers = filtered_deliveries.groupby('bowler')['player_dismissed'].count().reset_index()
TopBowlers.columns = ["bowler","total_wickets"]
TopBowlers = TopBowlers.sort_values(by ="total_wickets",ascending = False)
TopBowlers
# Out:
#               bowler  total_wickets
# 340       SL Malinga            170
# 7           A Mishra            156
# 126  Harbhajan Singh            150
# 264        PP Chawla            149
# 93          DJ Bravo            147
# ..               ...            ...
# 366      Sunny Gupta              0
# 139           J Dala              0
# 51          B Chipli              0
# 306           S Dube              0
# 243    NJ Rimmington              0
#
# [405 rows x 2 columns]

# %%
Top_10_bowlers_by_wickets = TopBowlers.head(10)
Top_10_bowlers_by_wickets
# Out:
#               bowler  total_wickets
# 340       SL Malinga            170
# 7           A Mishra            156
# 126  Harbhajan Singh            150
# 264        PP Chawla            149
# 93          DJ Bravo            147
# 53           B Kumar            133
# 269         R Ashwin            125
# 347        SP Narine            122
# 381         UT Yadav            119
# 282        RA Jadeja            108

# %% [markdown]
# ### SL Malinga	has took highest number of wickets that is 170

# %%
plt.figure(figsize=(12, 6))
bars = plt.bar(Top_10_bowlers_by_wickets['bowler'],Top_10_bowlers_by_wickets['total_wickets'], color='purple')
plt.xlabel('batsman')
plt.ylabel('total_runs')
plt.title('TopBowlers by Total Wickets')
plt.xticks(rotation=45, ha='right')  # Rotate x-axis labels and align them to the right
plt.tight_layout()


# Annotate the bars with win counts
for bar in bars:
    plt.annotate(str(bar.get_height()), (bar.get_x() + bar.get_width() / 2, bar.get_height()), ha='center', va='bottom')

# Display the bar chart
plt.show()

# %%
run_outs = deliveries[deliveries['dismissal_kind'] == "run out"]
run_outs
# Out:
#         match_id  inning                 batting_team            bowling_team  \
# 199            1       2  Royal Challengers Bangalore     Sunrisers Hyderabad
# 247            1       2  Royal Challengers Bangalore     Sunrisers Hyderabad
# 371            2       1               Mumbai Indians  Rising Pune Supergiant
# 1063           5       1  Royal Challengers Bangalore        Delhi Daredevils
# 1313           6       1                Gujarat Lions     Sunrisers Hyderabad
# ...          ...     ...                          ...                     ...
# 177016     11343       1              Kings XI Punjab   Kolkata Knight Riders
# 177195     11344       1             Rajasthan Royals          Delhi Capitals
# 178951     11415       1               Mumbai Indians     Chennai Super Kings
# 179033     11415       2          Chennai Super Kings          Mumbai Indians
# 179075     11415       2          Chennai Super Kings          Mumbai Indians
#
# ...

# %%
len(run_outs)
# Out:
# 852

# %%
most_runouts = run_outs.groupby('fielder')['player_dismissed'].count().reset_index()
most_runouts.columns = ["fielder","total_runouts"]
most_runouts = most_runouts.sort_values(by="total_runouts",ascending = False).head(10)
most_runouts
# Out:
#             fielder  total_runouts
# 146        MS Dhoni             23
# 183       RA Jadeja             20
# 243         V Kohli             17
# 211        SK Raina             16
# 10   AB de Villiers             14
# 102      KD Karthik             14
# 139       MK Pandey             14
# 165        PA Patel             12
# 58         DJ Bravo             12
# 26        AT Rayudu             10

# %%
most_runouts = run_outs.groupby('batsman')['player_dismissed'].count().reset_index()
most_runouts.columns = ["batsman","total_runouts"]
most_runouts = most_runouts.sort_values(by="total_runouts",ascending = False).head(10)
most_runouts
# Out:
#         batsman  total_runouts
# 152    MS Dhoni             21
# 195   RG Sharma             17
# 112  KD Karthik             16
# 74    G Gambhir             15
# 261     V Kohli             15
# 208    S Dhawan             14
# 228    SK Raina             12
# 205  RV Uthappa             12
# 27    AT Rayudu             12
# 273   YK Pathan             12

# %%
stumped_outs = deliveries[deliveries['dismissal_kind'] == "stumped"]
stumped_outs
# Out:
#         match_id  inning                 batting_team            bowling_team  \
# 1013           5       1  Royal Challengers Bangalore        Delhi Daredevils
# 3024          13       2                Gujarat Lions  Rising Pune Supergiant
# 3274          14       2          Sunrisers Hyderabad   Kolkata Knight Riders
# 4006          17       2  Royal Challengers Bangalore  Rising Pune Supergiant
# 4308          18       2        Kolkata Knight Riders        Delhi Daredevils
# ...          ...     ...                          ...                     ...
# 176657     11341       2               Delhi Capitals     Chennai Super Kings
# 176659     11341       2               Delhi Capitals     Chennai Super Kings
# 177237     11344       1             Rajasthan Royals          Delhi Capitals
# 178177     11412       1          Chennai Super Kings          Mumbai Indians
# 178977     11415       2          Chennai Super Kings          Mumbai Indians
#
# ...

# %%
len(stumped_outs)
# Out:
# 278

# %%
most_stumped = stumped_outs.groupby('fielder')['player_dismissed'].count().reset_index()
most_stumped.columns = ["fielder","total_stumped"]
most_stumped = most_stumped.sort_values(by="total_stumped",ascending = False).head(10)
most_stumped
# Out:
#           fielder  total_stumped
# 21       MS Dhoni             38
# 29     RV Uthappa             32
# 14     KD Karthik             29
# 33        WP Saha             18
# 25       PA Patel             16
# 1    AC Gilchrist             16
# 24        NV Ojha             10
# 13  KC Sangakkara              9
# 28        RR Pant              9
# 27      Q de Kock              8

# %%
most_stumped = stumped_outs.groupby('batsman')['player_dismissed'].count().reset_index()
most_stumped.columns = ["batsman","total_stumped"]
most_stumped = most_stumped.sort_values(by="total_stumped",ascending = False).head(10)
most_stumped
# Out:
#             batsman  total_stumped
# 117        SK Raina              8
# 108      RV Uthappa              7
# 14        AT Rayudu              7
# 39     F du Plessis              6
# 4    AB de Villiers              6
# 92         PA Patel              6
# 111        S Dhawan              5
# 28        DA Warner              5
# 71          M Vijay              5
# 86    Mandeep Singh              4

# %%
catch_outs = deliveries[deliveries['dismissal_kind'] == "caught"]
catch_outs
# Out:
#         match_id  inning                 batting_team  \
# 11             1       1          Sunrisers Hyderabad
# 64             1       1          Sunrisers Hyderabad
# 94             1       1          Sunrisers Hyderabad
# 165            1       2  Royal Challengers Bangalore
# 206            1       2  Royal Challengers Bangalore
# ...          ...     ...                          ...
# 178908     11415       1               Mumbai Indians
# 178921     11415       1               Mumbai Indians
# 178945     11415       1               Mumbai Indians
# 179019     11415       2          Chennai Super Kings
# 179067     11415       2          Chennai Super Kings
#
#                        bowling_team  over  ball       batsman   non_striker  \
# 11      Royal Challengers Bangalore     2     5     DA Warner      S Dhawan
# 64      Royal Challengers Bangalore    11     3      S Dhawan  MC Henriques
# 94      Royal Challengers Bangalore    16     2  MC Henriques  Yuvraj Singh
# ...

# %%
len(catch_outs)
# Out:
# 5348

# %%
most_caughtplayer = catch_outs.groupby('fielder')['player_dismissed'].count().reset_index()
most_caughtplayer.columns = ["fielder","total_caught"]
most_caughtplayer = most_caughtplayer.sort_values(by="total_caught",ascending = False).head(10)
most_caughtplayer
# Out:
#             fielder  total_caught
# 205      KD Karthik           109
# 407        SK Raina            99
# 276        MS Dhoni            98
# 18   AB de Villiers            93
# 367      RV Uthappa            84
# 350       RG Sharma            82
# 199      KA Pollard            76
# 464         V Kohli            73
# 309        PA Patel            69
# 374        S Dhawan            68

# %%
most_caughtplayer = catch_outs.groupby('batsman')['player_dismissed'].count().reset_index()
most_caughtplayer.columns = ["batsman","total_caught"]
most_caughtplayer = most_caughtplayer.sort_values(by="total_caught",ascending = False).head(10)
most_caughtplayer
# Out:
#           batsman  total_caught
# 350      SK Raina           112
# 314    RV Uthappa           108
# 300     RG Sharma           103
# 399       V Kohli            95
# 168    KD Karthik            85
# 421  Yuvraj Singh            84
# 110     G Gambhir            80
# 322      S Dhawan            79
# 417     YK Pathan            77
# 70       CH Gayle            75

# %%
bowled_outs = deliveries[deliveries['dismissal_kind'] == "bowled"]
bowled_outs
# Out:
#         match_id  inning                 batting_team  \
# 116            1       1          Sunrisers Hyderabad
# 160            1       2  Royal Challengers Bangalore
# 235            1       2  Royal Challengers Bangalore
# 274            2       1               Mumbai Indians
# 287            2       1               Mumbai Indians
# ...          ...     ...                          ...
# 178437     11413       1          Sunrisers Hyderabad
# 178700     11414       1               Delhi Capitals
# 178710     11414       1               Delhi Capitals
# 178811     11414       2          Chennai Super Kings
# 178901     11415       1               Mumbai Indians
#
#                        bowling_team  over  ball        batsman   non_striker  \
# 116     Royal Challengers Bangalore    19     4   Yuvraj Singh      DJ Hooda
# 160             Sunrisers Hyderabad     6     4  Mandeep Singh      CH Gayle
# 235             Sunrisers Hyderabad    18     4      S Aravind      TS Mills
# ...

# %%
len(bowled_outs)
# Out:
# 1581

# %%
most_bowled = bowled_outs.groupby('bowler')['player_dismissed'].count().reset_index()
most_bowled.columns = ["bowler","total_bowled"]
most_bowled = most_bowled.sort_values(by="total_bowled",ascending = False).head(10)
most_bowled
# Out:
#               bowler  total_bowled
# 212       SL Malinga            63
# 166        PP Chawla            43
# 215        SP Narine            35
# 33           B Kumar            35
# 75   Harbhajan Singh            29
# 180        RA Jadeja            27
# 65          DW Steyn            26
# 3           A Mishra            25
# 185         RP Singh            25
# 5            A Nehra            23

# %%
most_bowled = bowled_outs.groupby('batsman')['player_dismissed'].count().reset_index()
most_bowled.columns = ["batsman","total_bowled"]
most_bowled = most_bowled.sort_values(by="total_bowled",ascending = False).head(10)
most_bowled
# Out:
#         batsman  total_bowled
# 280   SR Watson            32
# 306     V Kohli            30
# 250    S Dhawan            28
# 95    G Gambhir            27
# 177   MK Pandey            24
# 72    DA Warner            23
# 232   RG Sharma            22
# 64     CH Gayle            22
# 208    PA Patel            22
# 137  KD Karthik            21

# %%
lbw_outs = deliveries[deliveries['dismissal_kind'] == "lbw"]
lbw_outs
# Out:
#         match_id  inning         batting_team                 bowling_team  \
# 289            2       1       Mumbai Indians       Rising Pune Supergiant
# 544            3       1        Gujarat Lions        Kolkata Knight Riders
# 1165           5       2     Delhi Daredevils  Royal Challengers Bangalore
# 1236           6       1        Gujarat Lions          Sunrisers Hyderabad
# 1245           6       1        Gujarat Lions          Sunrisers Hyderabad
# ...          ...     ...                  ...                          ...
# 178554     11413       2       Delhi Capitals          Sunrisers Hyderabad
# 178606     11414       1       Delhi Capitals          Chennai Super Kings
# 178943     11415       1       Mumbai Indians          Chennai Super Kings
# 179012     11415       2  Chennai Super Kings               Mumbai Indians
# 179077     11415       2  Chennai Super Kings               Mumbai Indians
#
# ...

# %%
len(lbw_outs)
# Out:
# 540

# %%
most_lbw = lbw_outs.groupby('bowler')['player_dismissed'].count().reset_index()
most_lbw.columns = ["bowler","total_lbw"]
most_lbw = most_lbw.sort_values(by="total_lbw",ascending = False).head(10)
most_lbw
# Out:
#              bowler  total_lbw
# 112       PP Chawla         16
# 145       SP Narine         16
# 128     Rashid Khan         14
# 115        R Ashwin         14
# 2          A Mishra         13
# 148  Sandeep Sharma         11
# 142      SL Malinga         11
# 122       RA Jadeja         11
# 169          Z Khan          9
# 90   M Muralitharan          9

# %%
most_lbw = lbw_outs.groupby('batsman')['player_dismissed'].count().reset_index()
most_lbw.columns = ["batsman","total_lbw"]
most_lbw = most_lbw.sort_values(by="total_lbw",ascending = False).head(10)
most_lbw
# Out:
#           batsman  total_lbw
# 25    BB McCullum         16
# 154    RV Uthappa         13
# 131      PA Patel         12
# 51       DR Smith         12
# 14      AM Rahane         11
# 145     RG Sharma         11
# 82     KD Karthik         11
# 100       M Vijay          9
# 175  SR Tendulkar          8
# 160      S Dhawan          8

# %%
caughtandbowled_out = deliveries[deliveries['dismissal_kind'] == "caught and bowled"]
caughtandbowled_out
# Out:
#         match_id  inning            batting_team                 bowling_team  \
# 316            2       1          Mumbai Indians       Rising Pune Supergiant
# 783            4       1  Rising Pune Supergiant              Kings XI Punjab
# 822            4       1  Rising Pune Supergiant              Kings XI Punjab
# 909            4       2         Kings XI Punjab       Rising Pune Supergiant
# 1204           5       2        Delhi Daredevils  Royal Challengers Bangalore
# ...          ...     ...                     ...                          ...
# 144213       610       1           Gujarat Lions          Sunrisers Hyderabad
# 146736       620       2           Gujarat Lions  Royal Challengers Bangalore
# 147449       624       1   Kolkata Knight Riders  Royal Challengers Bangalore
# 148850       630       1          Mumbai Indians                Gujarat Lions
# 149782       634       1     Sunrisers Hyderabad        Kolkata Knight Riders
#
# ...

# %%
len(caughtandbowled_out)
# Out:
# 211

# %%
most_caughtandbowled = caughtandbowled_out.groupby('bowler')['player_dismissed'].count().reset_index()
most_caughtandbowled.columns= ["bowler","total_caughtandbowled"]
most_caughtandbowled = most_caughtandbowled.sort_values(by="total_caughtandbowled",ascending = False).head(10)
most_caughtandbowled
# Out:
#              bowler  total_caughtandbowled
# 31  Harbhajan Singh                     10
# 23         DJ Bravo                      8
# 91        SP Narine                      7
# 45       KA Pollard                      6
# 90       SL Malinga                      5
# 89         SK Warne                      5
# 1        A Chandila                      5
# 13          B Kumar                      5
# 39       JD Unadkat                      4
# 27      DS Kulkarni                      4

# %%
most_caughtandbowled = caughtandbowled_out.groupby('batsman')['player_dismissed'].count().reset_index()
most_caughtandbowled.columns = ["batsman","total_caughtandbowled"]
most_caughtandbowled = most_caughtandbowled.sort_values(by="total_caughtandbowled",ascending = False).head(10)
most_caughtandbowled
# Out:
#           batsman  total_caughtandbowled
# 99       SK Raina                      7
# 88      RG Sharma                      6
# 10      AM Rahane                      5
# 87      RA Jadeja                      5
# 86       R Dravid                      5
# 14      AT Rayudu                      5
# 38      G Gambhir                      4
# 56  KC Sangakkara                      4
# 75       MS Dhoni                      4
# 69        M Vohra                      4

# %%
totalballsspelt = deliveries.groupby('bowler')['ball'].count().reset_index()
totalballsspelt.columns = ['bowler','balls_spelt']
totalballsspelt = totalballsspelt.sort_values(by = "balls_spelt",ascending = False).head(50)
totalballsspelt
# Out:
#               bowler  balls_spelt
# 126  Harbhajan Singh         3451
# 7           A Mishra         3172
# 264        PP Chawla         3157
# 269         R Ashwin         3016
# 340       SL Malinga         2974
# 93          DJ Bravo         2711
# 53           B Kumar         2707
# 251          P Kumar         2637
# 381         UT Yadav         2605
# 347        SP Narine         2600
# 282        RA Jadeja         2541
# 404           Z Khan         2276
# 108         DW Steyn         2207
# 281    R Vinay Kumar         2186
# 350        SR Watson         2137
# 133        IK Pathan         2113
# 130         I Sharma         1999
# 9            A Nehra         1974
# 265          PP Ojha         1945
# 292         RP Singh         1874
# 402        YS Chahal         1841
# 106      DS Kulkarni         1830
# 145        JA Morkel         1807
# 152        JH Kallis         1799
# 153        JJ Bumrah         1798
# 226        MM Sharma         1770
# ...

# %%
bowling_merge = pd.merge(TopBowlers,totalballsspelt,on = 'bowler')
bowling_merge
# Out:
#              bowler  total_wickets  balls_spelt
# 0        SL Malinga            170         2974
# 1          A Mishra            156         3172
# 2   Harbhajan Singh            150         3451
# 3         PP Chawla            149         3157
# 4          DJ Bravo            147         2711
# 5           B Kumar            133         2707
# 6          R Ashwin            125         3016
# 7         SP Narine            122         2600
# 8          UT Yadav            119         2605
# 9         RA Jadeja            108         2541
# 10          A Nehra            106         1974
# 11    R Vinay Kumar            105         2186
# 12           Z Khan            102         2276
# 13        YS Chahal            100         1841
# 14         DW Steyn             96         2207
# 15        SR Watson             92         2137
# 16        MM Sharma             91         1770
# 17          P Kumar             90         2637
# 18         RP Singh             90         1874
# ...

# %%
bowling_merge['bowling_strikerate'] = round((bowling_merge['balls_spelt']/bowling_merge['total_wickets']),2)
bowling_merge = bowling_merge.sort_values(by = 'bowling_strikerate',ascending = True)
bowling_merge

# ballspelt include all the balls even the wides, legbyes , etc
# Out:
#              bowler  total_wickets  balls_spelt  bowling_strikerate
# 25      Imran Tahir             79         1249               15.81
# 0        SL Malinga            170         2974               17.49
# 13        YS Chahal            100         1841               18.41
# 4          DJ Bravo            147         2711               18.44
# 10          A Nehra            106         1974               18.62
# 22   Sandeep Sharma             83         1546               18.63
# 29         MM Patel             74         1382               18.68
# 32   MJ McClenaghan             71         1346               18.96
# 34        CH Morris             70         1335               19.07
# 16        MM Sharma             91         1770               19.45
# 27       JD Unadkat             77         1541               20.01
# 44      Rashid Khan             55         1106               20.11
# 1          A Mishra            156         3172               20.33
# ...

# %%
bowling_merge_df = bowling_merge.head(10)
bowling_merge_df
# Out:
#             bowler  total_wickets  balls_spelt  bowling_strikerate
# 25     Imran Tahir             79         1249               15.81
# 0       SL Malinga            170         2974               17.49
# 13       YS Chahal            100         1841               18.41
# 4         DJ Bravo            147         2711               18.44
# 10         A Nehra            106         1974               18.62
# 22  Sandeep Sharma             83         1546               18.63
# 29        MM Patel             74         1382               18.68
# 32  MJ McClenaghan             71         1346               18.96
# 34       CH Morris             70         1335               19.07
# 16       MM Sharma             91         1770               19.45

# %% [markdown]
# ### Imran Tahir has the good bowling strikerate 15.81

# %%
totalruns_conceded = deliveries.groupby('bowler')['total_runs'].sum().reset_index()
totalruns_conceded.columns = ['bowler','total_runs']
totalruns_conceded = totalruns_conceded.sort_values(by='total_runs',ascending= False).head(100)
totalruns_conceded
# Out:
#               bowler  total_runs
# 264        PP Chawla        4153
# 126  Harbhajan Singh        4050
# 7           A Mishra        3850
# 93          DJ Bravo        3733
# 381         UT Yadav        3640
# ..               ...         ...
# 246  NM Coulter-Nile         739
# 394       WD Parnell         731
# 215         MA Starc         725
# 92      DE Bollinger         716
# 127    Harmeet Singh         713
#
# [100 rows x 2 columns]

# %%
bowling_average = pd.merge(totalruns_conceded,TopBowlers,on = "bowler")
bowling_average
# Out:
#              bowler  total_runs  total_wickets
# 0         PP Chawla        4153            149
# 1   Harbhajan Singh        4050            150
# 2          A Mishra        3850            156
# 3          DJ Bravo        3733            147
# 4          UT Yadav        3640            119
# ..              ...         ...            ...
# 95  NM Coulter-Nile         739             36
# 96       WD Parnell         731             26
# 97         MA Starc         725             34
# 98     DE Bollinger         716             37
# 99    Harmeet Singh         713             26
#
# [100 rows x 3 columns]

# %%
bowling_average['bowling_average'] = round((bowling_average['total_runs']/bowling_average['total_wickets']),2)
bowling_average = bowling_average.sort_values(by = "bowling_average",ascending = True)
bowling_average
# Out:
#              bowler  total_runs  total_wickets  bowling_average
# 98     DE Bollinger         716             37            19.35
# 93          S Gopal         753             38            19.82
# 95  NM Coulter-Nile         739             36            20.53
# 5        SL Malinga        3511            170            20.65
# 42      Imran Tahir        1656             79            20.96
# ..              ...         ...            ...              ...
# 90          BB Sran         786             18            43.67
# 66            B Lee        1126             25            45.04
# 65         SK Raina        1139             25            45.56
# 51         M Kartik        1418             31            45.74
# 54       TG Southee        1340             28            47.86
#
# [100 rows x 4 columns]

# %%
totalballsspelt['total_overs_spelt'] = totalballsspelt['balls_spelt']/6
totalballsspelt
# Out:
#               bowler  balls_spelt  total_overs_spelt
# 126  Harbhajan Singh         3451         575.166667
# 7           A Mishra         3172         528.666667
# 264        PP Chawla         3157         526.166667
# 269         R Ashwin         3016         502.666667
# 340       SL Malinga         2974         495.666667
# 93          DJ Bravo         2711         451.833333
# 53           B Kumar         2707         451.166667
# 251          P Kumar         2637         439.500000
# 381         UT Yadav         2605         434.166667
# 347        SP Narine         2600         433.333333
# 282        RA Jadeja         2541         423.500000
# 404           Z Khan         2276         379.333333
# 108         DW Steyn         2207         367.833333
# 281    R Vinay Kumar         2186         364.333333
# 350        SR Watson         2137         356.166667
# 133        IK Pathan         2113         352.166667
# 130         I Sharma         1999         333.166667
# ...

# %%
totalruns_conceded
# Out:
#               bowler  total_runs
# 264        PP Chawla        4153
# 126  Harbhajan Singh        4050
# 7           A Mishra        3850
# 93          DJ Bravo        3733
# 381         UT Yadav        3640
# ..               ...         ...
# 246  NM Coulter-Nile         739
# 394       WD Parnell         731
# 215         MA Starc         725
# 92      DE Bollinger         716
# 127    Harmeet Singh         713
#
# [100 rows x 2 columns]

# %%
Bowling_Economy = pd.merge(totalruns_conceded,totalballsspelt,on = 'bowler')
Bowling_Economy
# Out:
#              bowler  total_runs  balls_spelt  total_overs_spelt
# 0         PP Chawla        4153         3157         526.166667
# 1   Harbhajan Singh        4050         3451         575.166667
# 2          A Mishra        3850         3172         528.666667
# 3          DJ Bravo        3733         2711         451.833333
# 4          UT Yadav        3640         2605         434.166667
# 5        SL Malinga        3511         2974         495.666667
# 6          R Ashwin        3391         3016         502.666667
# 7           P Kumar        3342         2637         439.500000
# 8           B Kumar        3264         2707         451.166667
# 9         RA Jadeja        3221         2541         423.500000
# 10    R Vinay Kumar        3043         2186         364.333333
# 11        SP Narine        2939         2600         433.333333
# 12           Z Khan        2860         2276         379.333333
# 13        SR Watson        2751         2137         356.166667
# ...

# %%
Bowling_Economy['bowling_economy'] = round((Bowling_Economy['total_runs']/Bowling_Economy['total_overs_spelt']),2)
Bowling_Economy = Bowling_Economy.sort_values(by='bowling_economy', ascending = True)
Bowling_Economy
# Out:
#              bowler  total_runs  balls_spelt  total_overs_spelt  \
# 19         DW Steyn        2454         2207         367.833333
# 38   M Muralitharan        1765         1581         263.500000
# 6          R Ashwin        3391         3016         502.666667
# 11        SP Narine        2939         2600         433.333333
# 49      Rashid Khan        1257         1106         184.333333
# 1   Harbhajan Singh        4050         3451         575.166667
# 5        SL Malinga        3511         2974         495.666667
# 46         SK Warne        1465         1223         203.833333
# 48         M Kartik        1418         1182         197.000000
# 8           B Kumar        3264         2707         451.166667
# 2          A Mishra        3850         3172         528.666667
# 47        YK Pathan        1443         1184         197.333333
# 23          PP Ojha        2399         1945         324.166667
# 43         S Nadeem        1589         1283         213.833333
# ...

# %%
Bowling_df = Bowling_Economy[Bowling_Economy['balls_spelt']>600]
Bowling_df = Bowling_df.sort_values(by = 'bowling_economy', ascending = True).head(20)
Bowling_df
# Out:
#              bowler  total_runs  balls_spelt  total_overs_spelt  \
# 19         DW Steyn        2454         2207         367.833333
# 38   M Muralitharan        1765         1581         263.500000
# 6          R Ashwin        3391         3016         502.666667
# 11        SP Narine        2939         2600         433.333333
# 49      Rashid Khan        1257         1106         184.333333
# 1   Harbhajan Singh        4050         3451         575.166667
# 5        SL Malinga        3511         2974         495.666667
# 46         SK Warne        1465         1223         203.833333
# 48         M Kartik        1418         1182         197.000000
# 8           B Kumar        3264         2707         451.166667
# 2          A Mishra        3850         3172         528.666667
# 47        YK Pathan        1443         1184         197.333333
# 23          PP Ojha        2399         1945         324.166667
# 43         S Nadeem        1589         1283         213.833333
# ...

# %% [markdown]
# ### DW Steyn has the good bowling economy that is 6.67

# %%
zero_run_balls = deliveries[deliveries['total_runs'] == 0]
zero_run_balls
# Out:
#         match_id  inning         batting_team                 bowling_team  \
# 0              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# 1              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# 3              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# 5              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# 11             1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# ...          ...     ...                  ...                          ...
# 179057     11415       2  Chennai Super Kings               Mumbai Indians
# 179064     11415       2  Chennai Super Kings               Mumbai Indians
# 179067     11415       2  Chennai Super Kings               Mumbai Indians
# 179069     11415       2  Chennai Super Kings               Mumbai Indians
# 179077     11415       2  Chennai Super Kings               Mumbai Indians
#
# ...

# %%
dismissed_balls = deliveries[deliveries['player_dismissed'].notna()]
dismissed_balls
# Out:
#         match_id  inning                 batting_team  \
# 11             1       1          Sunrisers Hyderabad
# 64             1       1          Sunrisers Hyderabad
# 94             1       1          Sunrisers Hyderabad
# 116            1       1          Sunrisers Hyderabad
# 160            1       2  Royal Challengers Bangalore
# ...          ...     ...                          ...
# 179019     11415       2          Chennai Super Kings
# 179033     11415       2          Chennai Super Kings
# 179067     11415       2          Chennai Super Kings
# 179075     11415       2          Chennai Super Kings
# 179077     11415       2          Chennai Super Kings
#
#                        bowling_team  over  ball        batsman   non_striker  \
# 11      Royal Challengers Bangalore     2     5      DA Warner      S Dhawan
# 64      Royal Challengers Bangalore    11     3       S Dhawan  MC Henriques
# 94      Royal Challengers Bangalore    16     2   MC Henriques  Yuvraj Singh
# ...

# %%
dot_balls = zero_run_balls[~zero_run_balls.index.isin(dismissed_balls.index)]
dot_balls
# Out:
#         match_id  inning         batting_team                 bowling_team  \
# 0              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# 1              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# 3              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# 5              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# 12             1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# ...          ...     ...                  ...                          ...
# 179046     11415       2  Chennai Super Kings               Mumbai Indians
# 179056     11415       2  Chennai Super Kings               Mumbai Indians
# 179057     11415       2  Chennai Super Kings               Mumbai Indians
# 179064     11415       2  Chennai Super Kings               Mumbai Indians
# 179069     11415       2  Chennai Super Kings               Mumbai Indians
#
# ...

# %%
dot_balls_by_player = dot_balls.groupby('bowler')['total_runs'].count().reset_index()
dot_balls_by_player.columns = ['bowler','dotball_count']
dot_balls_by_player = dot_balls_by_player.sort_values(by = 'dotball_count',ascending = False)
dot_balls_by_player
# Out:
#               bowler  dotball_count
# 122  Harbhajan Singh           1090
# 52           B Kumar            976
# 244          P Kumar            976
# 331       SL Malinga            965
# 257        PP Chawla            947
# ..               ...            ...
# 291         RW Price              1
# 191      LMP Simmons              1
# 276        RA Shaikh              1
# 108         FY Fazal              1
# 224    Mandeep Singh              1
#
# [393 rows x 2 columns]

# %%
totalballsspelt
# Out:
#               bowler  balls_spelt  total_overs_spelt
# 126  Harbhajan Singh         3451         575.166667
# 7           A Mishra         3172         528.666667
# 264        PP Chawla         3157         526.166667
# 269         R Ashwin         3016         502.666667
# 340       SL Malinga         2974         495.666667
# 93          DJ Bravo         2711         451.833333
# 53           B Kumar         2707         451.166667
# 251          P Kumar         2637         439.500000
# 381         UT Yadav         2605         434.166667
# 347        SP Narine         2600         433.333333
# 282        RA Jadeja         2541         423.500000
# 404           Z Khan         2276         379.333333
# 108         DW Steyn         2207         367.833333
# 281    R Vinay Kumar         2186         364.333333
# 350        SR Watson         2137         356.166667
# 133        IK Pathan         2113         352.166667
# 130         I Sharma         1999         333.166667
# ...

# %%
Dotball_merge = pd.merge(totalballsspelt,dot_balls_by_player,on = 'bowler')
Dotball_merge = Dotball_merge.sort_values(by = 'dotball_count',ascending = False)
Dotball_merge
# Out:
#              bowler  balls_spelt  total_overs_spelt  dotball_count
# 0   Harbhajan Singh         3451         575.166667           1090
# 7           P Kumar         2637         439.500000            976
# 6           B Kumar         2707         451.166667            976
# 4        SL Malinga         2974         495.666667            965
# 2         PP Chawla         3157         526.166667            947
# 1          A Mishra         3172         528.666667            945
# 3          R Ashwin         3016         502.666667            938
# 9         SP Narine         2600         433.333333            906
# 12         DW Steyn         2207         367.833333            893
# 8          UT Yadav         2605         434.166667            816
# 11           Z Khan         2276         379.333333            760
# 15        IK Pathan         2113         352.166667            746
# 16         I Sharma         1999         333.166667            742
# ...

# %%
Dotball_merge['dotball_percentage'] = round((Dotball_merge['dotball_count']/Dotball_merge['balls_spelt'])*100,2)
Dotball_merge = Dotball_merge.sort_values(by = 'dotball_percentage', ascending = False).head(10)
Dotball_merge['dotball_percentage'] = Dotball_merge['dotball_percentage'].astype(str) + '%'
Dotball_merge
# Out:
#             bowler  balls_spelt  total_overs_spelt  dotball_count  \
# 12        DW Steyn         2207         367.833333            893
# 16        I Sharma         1999         333.166667            742
# 7          P Kumar         2637         439.500000            976
# 27        M Morkel         1699         283.166667            628
# 35        MM Patel         1382         230.333333            510
# 33  Sandeep Sharma         1546         257.666667            561
# 39      MG Johnson         1301         216.833333            470
# 6          B Kumar         2707         451.166667            976
# 15       IK Pathan         2113         352.166667            746
# 21     DS Kulkarni         1830         305.000000            640
#
#    dotball_percentage
# 12             40.46%
# 16             37.12%
# 7              37.01%
# 27             36.96%
# 35              36.9%
# 33             36.29%
# 39             36.13%
# 6              36.05%
# 15             35.31%
# ...

# %% [markdown]
# ### DW Steyn has the highest dotball percentage 40.46%

# %%
most_playerofmatch = matches["player_of_match"].value_counts().reset_index()
most_playerofmatch.columns = ["player","playerofmatchcount"]
most_playerofmatch = most_playerofmatch.sort_values(by='playerofmatchcount',ascending = False)
print(most_playerofmatch)
# Out:
#              player  playerofmatchcount
# 0          CH Gayle                  21
# 1    AB de Villiers                  20
# 2         RG Sharma                  17
# 3          MS Dhoni                  17
# 4         DA Warner                  17
# ..              ...                 ...
# 158      TG Southee                   1
# 157        TA Boult                   1
# 156   Kuldeep Yadav                   1
# 155        J Archer                   1
# 226       S Hetmyer                   1
#
# [227 rows x 2 columns]

# %%
top10most_playerofmatch = most_playerofmatch.head(10)

# %% [markdown]
# top10most_playerofmatch

# %% [markdown]
# ### CH Gayle has won player of match award most times that is 21 times

# %%
plt.figure(figsize=(12, 6))
bars = plt.bar(top10most_playerofmatch['player'], top10most_playerofmatch['playerofmatchcount'], color='skyblue')
plt.xlabel('player')
plt.ylabel('playerofmatchcount')
plt.title('Top 10 most Player of Match Count by Player')
plt.xticks(rotation=45, ha='right') 
plt.tight_layout()
for bar in bars:
    plt.annotate(str(bar.get_height()), (bar.get_x() + bar.get_width() / 2, bar.get_height()), ha='center', va='bottom')
plt.show()

# %%
season_df = deliveries.merge(matches[['id', 'season']], left_on='match_id', right_on='id')
season_wise_player_scores = season_df.groupby(['season', 'batsman'])['batsman_runs'].sum().reset_index()
season_wise_player_scores.columns = ['season', 'batsman', 'total_runs']
season_wise_player_scores = season_wise_player_scores.sort_values(by = 'total_runs',ascending = False).head(20)
print(season_wise_player_scores)
# Out:
#       season         batsman  total_runs
# 1383    2016         V Kohli         973
# 1278    2016       DA Warner         848
# 1595    2018   KS Williamson         747
# 684     2012        CH Gayle         733
# 910     2013      MEK Hussey         733
# 1696    2019       DA Warner         727
# 852     2013        CH Gayle         720
# 1637    2018         RR Pant         717
# 1256    2016  AB de Villiers         687
# 1593    2018        KL Rahul         678
# 1088    2014      RV Uthappa         660
# 1422    2017       DA Warner         641
# 983     2013         V Kohli         639
# 446     2010    SR Tendulkar         618
# 115     2008        SE Marsh         616
# 1543    2018       AT Rayudu         615
# 1731    2019        KL Rahul         610
# 502     2011        CH Gayle         608
# 706     2012       G Gambhir         590
# 1583    2018      JC Buttler         574

# %% [markdown]
# # Top Venues

# %%
Top_Venue = matches["venue"].value_counts().reset_index()
Top_Venue.columns = ["venue","Matches_Played"]
Top_Venue = Top_Venue.sort_values(by='Matches_Played',ascending = False)
print(Top_Venue)
# Out:
#                                                 venue  Matches_Played
# 0                                        Eden Gardens              77
# 2                                    Wankhede Stadium              73
# 1                               M Chinnaswamy Stadium              73
# 3                                    Feroz Shah Kotla              67
# 4           Rajiv Gandhi International Stadium, Uppal              56
# 5                     MA Chidambaram Stadium, Chepauk              49
# 6                              Sawai Mansingh Stadium              47
# 7          Punjab Cricket Association Stadium, Mohali              35
# 8             Maharashtra Cricket Association Stadium              21
# 10                         Dr DY Patil Sports Academy              17
# 9                          Subrata Roy Sahara Stadium              17
# 11                                          Kingsmead              15
# ...

# %%
top10venues = Top_Venue.head(10)
top10venues
# Out:
#                                          venue  Matches_Played
# 0                                 Eden Gardens              77
# 2                             Wankhede Stadium              73
# 1                        M Chinnaswamy Stadium              73
# 3                             Feroz Shah Kotla              67
# 4    Rajiv Gandhi International Stadium, Uppal              56
# 5              MA Chidambaram Stadium, Chepauk              49
# 6                       Sawai Mansingh Stadium              47
# 7   Punjab Cricket Association Stadium, Mohali              35
# 8      Maharashtra Cricket Association Stadium              21
# 10                  Dr DY Patil Sports Academy              17

# %%
plt.figure(figsize=(12, 6))
bars = plt.bar(top10venues['venue'], top10venues['Matches_Played'], color='purple')
plt.xlabel('venue')
plt.ylabel('Matches_Played')
plt.title('Top 10 Venues to host Matches')
plt.xticks(rotation=45, ha='right')  # Rotate x-axis labels and align them to the right
plt.tight_layout()

# Annotate the bars with win counts
for bar in bars:
    plt.annotate(str(bar.get_height()), (bar.get_x() + bar.get_width() / 2, bar.get_height()), ha='center', va='bottom')

# Display the bar chart
plt.show()

# %% [markdown]
# ### Eden Gardens is the top Venue

# %% [markdown]
# # Season_2019

# %%
matches_2019 = matches[matches['season'] == 2019]
matches_2019
# Out:
#         id  season           city      date                            team1  \
# 696  11137    2019        Chennai  23/03/19      Royal Challengers Bangalore
# 697  11138    2019        Kolkata  24/03/19              Sunrisers Hyderabad
# 698  11139    2019         Mumbai  24/03/19  Delhi Daredevils/Delhi Capitals
# 699  11140    2019         Jaipur  25/03/19                  Kings XI Punjab
# 700  11141    2019          Delhi  26/03/19  Delhi Daredevils/Delhi Capitals
# 701  11142    2019        Kolkata  27/03/19            Kolkata Knight Riders
# 702  11143    2019      Bengaluru  28/03/19                   Mumbai Indians
# 703  11144    2019      Hyderabad  29/03/19                 Rajasthan Royals
# 704  11145    2019         Mohali  30/03/19                   Mumbai Indians
# 705  11146    2019          Delhi  30/03/19            Kolkata Knight Riders
# 706  11147    2019      Hyderabad  31/03/19              Sunrisers Hyderabad
# ...

# %%
len(matches_2019)
# Out:
# 60

# %%
top_venues_2019 = matches_2019['venue'].value_counts().reset_index()
top_venues_2019.columns = ['venue','Count']
top_venues_2019 = top_venues_2019.sort_values(by = 'Count',ascending = False)
top_venues_2019
# Out:
#                                 venue  Count
# 0           M. A. Chidambaram Stadium      8
# 1  Rajiv Gandhi Intl. Cricket Stadium      8
# 2                        Eden Gardens      7
# 3                    Wankhede Stadium      7
# 4              Sawai Mansingh Stadium      7
# 5             Feroz Shah Kotla Ground      7
# 6              M. Chinnaswamy Stadium      7
# 7                   IS Bindra Stadium      7
# 8                    ACA-VDCA Stadium      2

# %%
most_won_team_2019 = matches_2019['winner'].value_counts().reset_index()
most_won_team_2019.columns = ['winner','wins_count']
most_won_team_2019 = most_won_team_2019.sort_values(by = 'wins_count', ascending = False)
most_won_team_2019
# Out:
#                             winner  wins_count
# 0                   Mumbai Indians          11
# 1              Chennai Super Kings          10
# 2  Delhi Daredevils/Delhi Capitals          10
# 3            Kolkata Knight Riders           6
# 4                  Kings XI Punjab           6
# 5              Sunrisers Hyderabad           6
# 6                 Rajasthan Royals           5
# 7      Royal Challengers Bangalore           5
# 8                       No Results           1

# %%
most_player_of_match_2019 = matches_2019['player_of_match'].value_counts().reset_index()
most_player_of_match_2019.columns = ['player_of_match','Count']
most_player_of_match_2019 = most_player_of_match_2019.sort_values(by = 'Count',ascending = False).head(10)
most_player_of_match_2019
# Out:
#     player_of_match  Count
# 0        AD Russell      4
# 2           RR Pant      3
# 3         JJ Bumrah      3
# 4          MS Dhoni      3
# 1         HH Pandya      3
# 8          KL Rahul      2
# 11        DA Warner      2
# 10        SR Watson      2
# 9   Harbhajan Singh      2
# 7          S Dhawan      2

# %%
highest_winbyruns_2019 = matches_2019.groupby('team1')['win_by_runs'].max().reset_index()
highest_winbyruns_2019.columns = ['team','winbyruns']
highest_winbyruns_2019 = highest_winbyruns_2019.sort_values(by = 'winbyruns',ascending = False).head(10)
highest_winbyruns_2019
# Out:
#                               team  winbyruns
# 7              Sunrisers Hyderabad        118
# 0              Chennai Super Kings         80
# 4                   Mumbai Indians         46
# 1  Delhi Daredevils/Delhi Capitals         39
# 3            Kolkata Knight Riders         34
# 6      Royal Challengers Bangalore         17
# 2                  Kings XI Punjab         14
# 5                 Rajasthan Royals          0

# %%
highest_winbywickets_2019 = matches_2019.groupby('team1')['win_by_wickets'].max().reset_index()
highest_winbywickets_2019.columns = ['team','winbywickets']
highest_winbywickets_2019 = highest_winbywickets_2019.sort_values(by = 'winbywickets',ascending = False).head(10)
highest_winbywickets_2019
# Out:
#                               team  winbywickets
# 3            Kolkata Knight Riders             9
# 2                  Kings XI Punjab             8
# 4                   Mumbai Indians             8
# 5                 Rajasthan Royals             8
# 6      Royal Challengers Bangalore             7
# 7              Sunrisers Hyderabad             7
# 0              Chennai Super Kings             6
# 1  Delhi Daredevils/Delhi Capitals             6

# %%
toss_decision_2019 = matches_2019['toss_decision'].value_counts().reset_index()
toss_decision_2019.columns = ['toss','count']
toss_decision_2019
# Out:
#     toss  count
# 0  field     50
# 1    bat     10

# %%
tosswinner_matchwinner_2019 = matches_2019[matches_2019['toss_winner'] == matches_2019['winner']]
tosswinner_matchwinner_2019
# Out:
#         id  season           city      date                            team1  \
# 696  11137    2019        Chennai  23/03/19      Royal Challengers Bangalore
# 697  11138    2019        Kolkata  24/03/19              Sunrisers Hyderabad
# 704  11145    2019         Mohali  30/03/19                   Mumbai Indians
# 705  11146    2019          Delhi  30/03/19            Kolkata Knight Riders
# 709  11150    2019         Jaipur  02/04/19      Royal Challengers Bangalore
# 711  11152    2019          Delhi  04/04/19  Delhi Daredevils/Delhi Capitals
# 712  11153    2019      Bengaluru  05/04/19      Royal Challengers Bangalore
# 713  11309    2019        Chennai  06/04/19              Chennai Super Kings
# 715  11311    2019      Bengaluru  07/04/19      Royal Challengers Bangalore
# 716  11312    2019         Jaipur  07/04/19                 Rajasthan Royals
# 717  11313    2019         Mohali  08/04/19              Sunrisers Hyderabad
# ...

# %%
len(tosswinner_matchwinner_2019)
# Out:
# 36

# %%
fieldfirst_matchwinner_2019 = matches_2019[(matches_2019["toss_decision"] == "field") & (matches_2019['toss_winner'] == matches_2019['winner'])]
fieldfirst_matchwinner_2019
# Out:
#         id  season           city      date                            team1  \
# 696  11137    2019        Chennai  23/03/19      Royal Challengers Bangalore
# 697  11138    2019        Kolkata  24/03/19              Sunrisers Hyderabad
# 704  11145    2019         Mohali  30/03/19                   Mumbai Indians
# 705  11146    2019          Delhi  30/03/19            Kolkata Knight Riders
# 709  11150    2019         Jaipur  02/04/19      Royal Challengers Bangalore
# 711  11152    2019          Delhi  04/04/19  Delhi Daredevils/Delhi Capitals
# 712  11153    2019      Bengaluru  05/04/19      Royal Challengers Bangalore
# 715  11311    2019      Bengaluru  07/04/19      Royal Challengers Bangalore
# 716  11312    2019         Jaipur  07/04/19                 Rajasthan Royals
# 717  11313    2019         Mohali  08/04/19              Sunrisers Hyderabad
# 718  11314    2019        Chennai  09/04/19            Kolkata Knight Riders
# ...

# %%
len(fieldfirst_matchwinner_2019)
# Out:
# 31

# %%
batfirst_matchwinner_2019 = matches_2019[(matches_2019["toss_decision"] == "bat") & (matches_2019['toss_winner'] == matches_2019['winner'])]
batfirst_matchwinner_2019
# Out:
#         id  season       city      date                            team1  \
# 713  11309    2019    Chennai  06/04/19              Chennai Super Kings
# 729  11325    2019      Delhi  18/04/19                   Mumbai Indians
# 741  11337    2019      Delhi  28/04/19  Delhi Daredevils/Delhi Capitals
# 746  11342    2019     Mumbai  02/05/19                   Mumbai Indians
# 755  11415    2019  Hyderabad  12/05/19                   Mumbai Indians
#
#                                team2                      toss_winner  \
# 713                  Kings XI Punjab              Chennai Super Kings
# 729  Delhi Daredevils/Delhi Capitals                   Mumbai Indians
# 741      Royal Challengers Bangalore  Delhi Daredevils/Delhi Capitals
# 746              Sunrisers Hyderabad                   Mumbai Indians
# 755              Chennai Super Kings                   Mumbai Indians
#
#     toss_decision  result  dl_applied                           winner  \
# ...

# %%
len(batfirst_matchwinner_2019)
# Out:
# 5

# %%
match_ids_2019 = matches_2019['id'].unique()
deliveries_2019 = deliveries[deliveries['match_id'].isin(match_ids_2019)]
deliveries_2019
# Out:
#         match_id  inning                 batting_team         bowling_team  \
# 164750     11137       1  Royal Challengers Bangalore  Chennai Super Kings
# 164751     11137       1  Royal Challengers Bangalore  Chennai Super Kings
# 164752     11137       1  Royal Challengers Bangalore  Chennai Super Kings
# 164753     11137       1  Royal Challengers Bangalore  Chennai Super Kings
# 164754     11137       1  Royal Challengers Bangalore  Chennai Super Kings
# ...          ...     ...                          ...                  ...
# 179073     11415       2          Chennai Super Kings       Mumbai Indians
# 179074     11415       2          Chennai Super Kings       Mumbai Indians
# 179075     11415       2          Chennai Super Kings       Mumbai Indians
# 179076     11415       2          Chennai Super Kings       Mumbai Indians
# 179077     11415       2          Chennai Super Kings       Mumbai Indians
#
# ...

# %%
top_batsman_2019 = deliveries_2019.groupby(['batsman','batting_team'])['batsman_runs'].sum().reset_index()
top_batsman_2019.columns = ['batsman','Team','Batsman_Runs']
top_batsman_2019 = top_batsman_2019.sort_values(by ='Batsman_Runs',ascending = False).head(30)
top_batsman_2019
# Out:
#             batsman                         Team  Batsman_Runs
# 27        DA Warner          Sunrisers Hyderabad           727
# 62         KL Rahul              Kings XI Punjab           610
# 96        Q de Kock               Mumbai Indians           555
# 5        AD Russell        Kolkata Knight Riders           545
# 111        S Dhawan               Delhi Capitals           542
# 22         CH Gayle              Kings XI Punjab           523
# 107         RR Pant               Delhi Capitals           511
# 128         SS Iyer               Delhi Capitals           484
# 136         V Kohli  Royal Challengers Bangalore           472
# 47       J Bairstow          Sunrisers Hyderabad           468
# 3    AB de Villiers  Royal Challengers Bangalore           454
# 9          AS Yadav               Mumbai Indians           438
# 80         MS Dhoni          Chennai Super Kings           436
# 40        HH Pandya               Mumbai Indians           433
# ...

# %%
balls_played_by_batsman_2019 = deliveries_2019.groupby('batsman')['ball'].count().reset_index()
balls_played_by_batsman_2019.columns = ["batsman","balls_played"]
balls_played_by_batsman_2019 = balls_played_by_batsman_2019.sort_values(by="balls_played",ascending = False)
balls_played_by_batsman_2019
# Out:
#           batsman  balls_played
# 27      DA Warner           496
# 62       KL Rahul           447
# 96      Q de Kock           406
# 128       SS Iyer           398
# 111      S Dhawan           392
# ..            ...           ...
# 48        J Denly             1
# 52      JJ Bumrah             1
# 17   Basil Thampi             1
# 53        K Ahmed             1
# 92          P Raj             1
#
# [144 rows x 2 columns]

# %%
batsman_2019 = pd.merge(top_batsman_2019,balls_played_by_batsman_2019,on = 'batsman')
batsman_2019
# Out:
#            batsman                         Team  Batsman_Runs  balls_played
# 0        DA Warner          Sunrisers Hyderabad           727           496
# 1         KL Rahul              Kings XI Punjab           610           447
# 2        Q de Kock               Mumbai Indians           555           406
# 3       AD Russell        Kolkata Knight Riders           545           274
# 4         S Dhawan               Delhi Capitals           542           392
# 5         CH Gayle              Kings XI Punjab           523           338
# 6          RR Pant               Delhi Capitals           511           311
# 7          SS Iyer               Delhi Capitals           484           398
# 8          V Kohli  Royal Challengers Bangalore           472           332
# 9       J Bairstow          Sunrisers Hyderabad           468           293
# 10  AB de Villiers  Royal Challengers Bangalore           454           294
# ...

# %%
batsman_2019['Strike_Rate'] = round((batsman_2019['Batsman_Runs']/batsman_2019['balls_played'])*100)
batsman_2019['Strike_Rate'] = batsman_2019['Strike_Rate'].astype(str) + '%'
batsman_2019 = batsman_2019.sort_values(by='Strike_Rate',ascending = False).head(10)
print(batsman_2019)
# Out:
#            batsman                         Team  Batsman_Runs  balls_played  \
# 3       AD Russell        Kolkata Knight Riders           545           274
# 13       HH Pandya               Mumbai Indians           433           225
# 6          RR Pant               Delhi Capitals           511           311
# 9       J Bairstow          Sunrisers Hyderabad           468           293
# 5         CH Gayle              Kings XI Punjab           523           338
# 10  AB de Villiers  Royal Challengers Bangalore           454           294
# 27      JC Buttler             Rajasthan Royals           329           214
# 22       SV Samson             Rajasthan Royals           358           238
# 0        DA Warner          Sunrisers Hyderabad           727           496
# 23          N Rana        Kolkata Knight Riders           355           242
#
#    Strike_Rate
# 3       199.0%
# 13      192.0%
# 6       164.0%
# 9       160.0%
# 5       155.0%
# 10      154.0%
# 27      154.0%
# ...

# %%
boundary_deliveries_2019 = deliveries_2019[(deliveries_2019['batsman_runs'] == 4) | (deliveries_2019['batsman_runs'] == 6)]
Boundaries_by_Player_2019 = boundary_deliveries_2019.groupby('batsman')['batsman_runs'].sum().reset_index()
Boundaries_by_Player_2019.columns = ['batsman','boundary_runs']
Boundaries_by_Player_2019 = Boundaries_by_Player_2019.sort_values(by = 'boundary_runs', ascending = False)
Boundaries_by_Player_2019
# Out:
#           batsman  boundary_runs
# 4      AD Russell            438
# 18       CH Gayle            392
# 22      DA Warner            358
# 44       KL Rahul            350
# 70      Q de Kock            334
# ..            ...            ...
# 20  CR Brathwaite              4
# 10     Avesh Khan              4
# 65         P Negi              4
# 25      DL Chahar              4
# 26    DS Kulkarni              4
#
# [108 rows x 2 columns]

# %%
batsman_boundaries_2019 = pd.merge(top_batsman_2019,Boundaries_by_Player_2019,on = 'batsman').head(50)
batsman_boundaries_2019
# Out:
#            batsman                         Team  Batsman_Runs  boundary_runs
# 0        DA Warner          Sunrisers Hyderabad           727            358
# 1         KL Rahul              Kings XI Punjab           610            350
# 2        Q de Kock               Mumbai Indians           555            334
# 3       AD Russell        Kolkata Knight Riders           545            438
# 4         S Dhawan               Delhi Capitals           542            326
# 5         CH Gayle              Kings XI Punjab           523            392
# 6          RR Pant               Delhi Capitals           511            310
# 7          SS Iyer               Delhi Capitals           484            252
# 8          V Kohli  Royal Challengers Bangalore           472            262
# 9       J Bairstow          Sunrisers Hyderabad           468            308
# 10  AB de Villiers  Royal Challengers Bangalore           454            280
# ...

# %%
batsman_boundaries_2019['boundary_percentage'] = round((batsman_boundaries_2019['boundary_runs']/batsman_boundaries_2019['Batsman_Runs'])*100,2)
batsman_boundaries_2019['boundary_percentage'] = batsman_boundaries_2019['boundary_percentage'].astype(str) + '%'
batsman_boundaries_2019 = batsman_boundaries_2019.sort_values(by = 'boundary_percentage',ascending = False ).head(10)
batsman_boundaries_2019
# Out:
#        batsman                         Team  Batsman_Runs  boundary_runs  \
# 3   AD Russell        Kolkata Knight Riders           545            438
# 5     CH Gayle              Kings XI Punjab           523            392
# 27  JC Buttler             Rajasthan Royals           329            240
# 15   SR Watson          Chennai Super Kings           417            288
# 13   HH Pandya               Mumbai Indians           433            296
# 14     CA Lynn        Kolkata Knight Riders           422            286
# 23      N Rana        Kolkata Knight Riders           355            238
# 9   J Bairstow          Sunrisers Hyderabad           468            308
# 21      P Shaw               Delhi Capitals           366            238
# 20    PA Patel  Royal Challengers Bangalore           392            252
#
#    boundary_percentage
# 3               80.37%
# 5               74.95%
# 27              72.95%
# 15              69.06%
# 13              68.36%
# ...

# %%
Player_dismissals_2019 = deliveries_2019.groupby('batsman')['player_dismissed'].count().reset_index()
Player_dismissals_2019.columns = ['batsman','Nooftimes_dismissed']
Player_dismissals_2019 = Player_dismissals_2019.sort_values(by="Nooftimes_dismissed",ascending = False)
Player_dismissals_2019
# Out:
#          batsman  Nooftimes_dismissed
# 127    SR Watson                   17
# 122     SK Raina                   16
# 93        P Shaw                   15
# 128      SS Iyer                   15
# 94      PA Patel                   15
# ..           ...                  ...
# 119     S Sharma                    0
# 43      I Sharma                    0
# 78     MM Sharma                    0
# 58   KC Cariappa                    0
# 0       A Joseph                    0
#
# [144 rows x 2 columns]

# %%
batting_avg_2019 = pd.merge(top_batsman_2019,Player_dismissals_2019,on = 'batsman').head(50)
batting_avg_2019
# Out:
#            batsman                         Team  Batsman_Runs  \
# 0        DA Warner          Sunrisers Hyderabad           727
# 1         KL Rahul              Kings XI Punjab           610
# 2        Q de Kock               Mumbai Indians           555
# 3       AD Russell        Kolkata Knight Riders           545
# 4         S Dhawan               Delhi Capitals           542
# 5         CH Gayle              Kings XI Punjab           523
# 6          RR Pant               Delhi Capitals           511
# 7          SS Iyer               Delhi Capitals           484
# 8          V Kohli  Royal Challengers Bangalore           472
# 9       J Bairstow          Sunrisers Hyderabad           468
# 10  AB de Villiers  Royal Challengers Bangalore           454
# 11        AS Yadav               Mumbai Indians           438
# 12        MS Dhoni          Chennai Super Kings           436
# 13       HH Pandya               Mumbai Indians           433
# ...

# %%
batting_avg_2019['Batting_Average'] = round((batting_avg_2019['Batsman_Runs']/batting_avg_2019['Nooftimes_dismissed']),2)
batting_avg_2019 = batting_avg_2019.sort_values(by = 'Batting_Average',ascending = False).head(20)
batting_avg_2019
# Out:
#            batsman                         Team  Batsman_Runs  \
# 12        MS Dhoni          Chennai Super Kings           436
# 0        DA Warner          Sunrisers Hyderabad           727
# 3       AD Russell        Kolkata Knight Riders           545
# 9       J Bairstow          Sunrisers Hyderabad           468
# 1         KL Rahul              Kings XI Punjab           610
# 13       HH Pandya               Mumbai Indians           433
# 27      JC Buttler             Rajasthan Royals           329
# 10  AB de Villiers  Royal Challengers Bangalore           454
# 24       MK Pandey          Sunrisers Hyderabad           350
# 5         CH Gayle              Kings XI Punjab           523
# 2        Q de Kock               Mumbai Indians           555
# 6          RR Pant               Delhi Capitals           511
# 16    F du Plessis          Chennai Super Kings           412
# 26       SPD Smith             Rajasthan Royals           334
# ...

# %%
HIS_2019 = deliveries_2019.groupby(['match_id','batsman'])['batsman_runs'].sum().reset_index()
HIS_2019.columns = ['match_id','batsman','batsman_runs']
HIS_2019 = HIS_2019.sort_values(by = 'batsman_runs', ascending = False).head(10)
HIS_2019
# Out:
#      match_id     batsman  batsman_runs
# 146     11147  J Bairstow           115
# 570     11331   AM Rahane           108
# 113     11144   SV Samson           106
# 398     11319    CH Gayle           105
# 346     11315    KL Rahul           104
# 145     11147   DA Warner           101
# 613     11334  KD Karthik           101
# 136     11146      P Shaw           100
# 509     11326     V Kohli           100
# 380     11317    S Dhawan            98

# %%
TopBatsman_2019 = deliveries_2019.groupby(['batsman','batting_team'])['batsman_runs'].count().reset_index()
TopBatsman_2019.columns = ["batsman","batting_team","batsman_run"]
TopBatsman_2019 = TopBatsman_2019.sort_values(by ="batsman_run",ascending = False).head(10)
TopBatsman_2019
# Out:
#           batsman                 batting_team  batsman_run
# 27      DA Warner          Sunrisers Hyderabad          496
# 62       KL Rahul              Kings XI Punjab          447
# 96      Q de Kock               Mumbai Indians          406
# 128       SS Iyer               Delhi Capitals          398
# 111      S Dhawan               Delhi Capitals          392
# 22       CH Gayle              Kings XI Punjab          338
# 136       V Kohli  Royal Challengers Bangalore          332
# 9        AS Yadav               Mumbai Indians          329
# 33   F du Plessis          Chennai Super Kings          326
# 127     SR Watson          Chennai Super Kings          322

# %%
# Orange Cap Holder in 2019 is DA Warner

# %%
dismissal_kind_2019 = deliveries_2019['dismissal_kind'].value_counts().reset_index()
dismissal_kind_2019.columns = ['dismissal_kind','Count']
dismissal_kind_2019 = dismissal_kind_2019.sort_values(by = 'Count',ascending = False)
dismissal_kind_2019
# Out:
#           dismissal_kind  Count
# 0                 caught    487
# 1                 bowled     86
# 2                    lbw     46
# 3                run out     39
# 4                stumped     16
# 5           retired hurt      1
# 6             hit wicket      1
# 7  obstructing the field      1

# %%
dismissals_to_exclude_2019 = ['run out', 'obstructing the field','retired hurt']

filtered_deliveries_2019 = deliveries_2019[~deliveries_2019['dismissal_kind'].isin(dismissals_to_exclude_2019)]

TopBowlers_2019 = filtered_deliveries_2019.groupby(['bowler','bowling_team'])['player_dismissed'].count().reset_index()
TopBowlers_2019.columns = ["bowler","bowling_team","total_wickets"]
TopBowlers_2019 = TopBowlers_2019.sort_values(by ="total_wickets",ascending = False).head(10)
TopBowlers_2019
# Out:
#               bowler                 bowling_team  total_wickets
# 32       Imran Tahir          Chennai Super Kings             26
# 43          K Rabada               Delhi Capitals             25
# 20         DL Chahar          Chennai Super Kings             22
# 79           S Gopal             Rajasthan Royals             20
# 38         JJ Bumrah               Mumbai Indians             19
# 60    Mohammed Shami              Kings XI Punjab             19
# 39           K Ahmed          Sunrisers Hyderabad             19
# 103        YS Chahal  Royal Challengers Bangalore             18
# 76       Rashid Khan          Sunrisers Hyderabad             17
# 29   Harbhajan Singh          Chennai Super Kings             16

# %%
# purple cap holder Imran tahir

# %%
totalballsspelt_2019 = deliveries_2019.groupby('bowler')['ball'].count().reset_index()
totalballsspelt_2019.columns = ['bowler','balls_spelt']
totalballsspelt_2019 = totalballsspelt_2019.sort_values(by = "balls_spelt",ascending = False).head(50)
totalballsspelt_2019
# Out:
#               bowler  balls_spelt
# 20         DL Chahar          403
# 32       Imran Tahir          389
# 38         JJ Bumrah          381
# 10           B Kumar          367
# 76       Rashid Khan          367
# 70          R Ashwin          343
# 60    Mohammed Shami          331
# 74         RA Jadeja          329
# 103        YS Chahal          308
# 6           AR Patel          307
# 63           N Saini          300
# 43          K Rabada          297
# 79           S Gopal          289
# 75         RD Chahar          287
# 30          I Sharma          286
# 45         KH Pandya          282
# 89        SL Malinga          280
# 92         SP Narine          273
# 27         HH Pandya          269
# 29   Harbhajan Singh          269
# 69         PP Chawla          267
# 86          S Sharma          265
# 33          J Archer          265
# 18          DJ Bravo          263
# 65         P Krishna          260
# 1           A Mishra          243
# ...

# %%
bowling_merge_2019 = pd.merge(TopBowlers_2019,totalballsspelt_2019,on = 'bowler')
bowling_merge_2019
# Out:
#             bowler                 bowling_team  total_wickets  balls_spelt
# 0      Imran Tahir          Chennai Super Kings             26          389
# 1         K Rabada               Delhi Capitals             25          297
# 2        DL Chahar          Chennai Super Kings             22          403
# 3          S Gopal             Rajasthan Royals             20          289
# 4        JJ Bumrah               Mumbai Indians             19          381
# 5   Mohammed Shami              Kings XI Punjab             19          331
# 6          K Ahmed          Sunrisers Hyderabad             19          222
# 7        YS Chahal  Royal Challengers Bangalore             18          308
# 8      Rashid Khan          Sunrisers Hyderabad             17          367
# 9  Harbhajan Singh          Chennai Super Kings             16          269

# %%
bowling_merge_2019['bowling_strikerate'] = round((bowling_merge_2019['balls_spelt']/bowling_merge_2019['total_wickets']),2)
bowling_merge_2019 = bowling_merge_2019.sort_values(by = 'bowling_strikerate',ascending = True)
bowling_merge_2019
# Out:
#             bowler                 bowling_team  total_wickets  balls_spelt  \
# 6          K Ahmed          Sunrisers Hyderabad             19          222
# 1         K Rabada               Delhi Capitals             25          297
# 3          S Gopal             Rajasthan Royals             20          289
# 0      Imran Tahir          Chennai Super Kings             26          389
# 9  Harbhajan Singh          Chennai Super Kings             16          269
# 7        YS Chahal  Royal Challengers Bangalore             18          308
# 5   Mohammed Shami              Kings XI Punjab             19          331
# 2        DL Chahar          Chennai Super Kings             22          403
# 4        JJ Bumrah               Mumbai Indians             19          381
# 8      Rashid Khan          Sunrisers Hyderabad             17          367
#
#    bowling_strikerate
# 6               11.68
# 1               11.88
# 3               14.45
# 0               14.96
# ...

# %%
bowling_merge_df_2019 = bowling_merge_2019.head(10)
bowling_merge_df_2019
# Out:
#             bowler                 bowling_team  total_wickets  balls_spelt  \
# 6          K Ahmed          Sunrisers Hyderabad             19          222
# 1         K Rabada               Delhi Capitals             25          297
# 3          S Gopal             Rajasthan Royals             20          289
# 0      Imran Tahir          Chennai Super Kings             26          389
# 9  Harbhajan Singh          Chennai Super Kings             16          269
# 7        YS Chahal  Royal Challengers Bangalore             18          308
# 5   Mohammed Shami              Kings XI Punjab             19          331
# 2        DL Chahar          Chennai Super Kings             22          403
# 4        JJ Bumrah               Mumbai Indians             19          381
# 8      Rashid Khan          Sunrisers Hyderabad             17          367
#
#    bowling_strikerate
# 6               11.68
# 1               11.88
# 3               14.45
# 0               14.96
# ...

# %%
totalruns_conceded_2019 = deliveries_2019.groupby('bowler')['total_runs'].sum().reset_index()
totalruns_conceded_2019.columns = ['bowler','total_runs']
totalruns_conceded_2019 = totalruns_conceded_2019.sort_values(by='total_runs',ascending= False).head(100)
totalruns_conceded_2019
# Out:
#             bowler  total_runs
# 20       DL Chahar         503
# 60  Mohammed Shami         493
# 10         B Kumar         485
# 89      SL Malinga         477
# 38       JJ Bumrah         459
# ..             ...         ...
# 8     Ankit Sharma          22
# 19        DJ Hooda          21
# 2            A Roy          14
# 49   L Livingstone          13
# 25        H Vihari           9
#
# [100 rows x 2 columns]

# %%
bowling_average_2019 = pd.merge(totalruns_conceded_2019,TopBowlers_2019,on = "bowler")
bowling_average_2019
# Out:
#             bowler  total_runs                 bowling_team  total_wickets
# 0        DL Chahar         503          Chennai Super Kings             22
# 1   Mohammed Shami         493              Kings XI Punjab             19
# 2        JJ Bumrah         459               Mumbai Indians             19
# 3      Imran Tahir         454          Chennai Super Kings             26
# 4        YS Chahal         414  Royal Challengers Bangalore             18
# 5      Rashid Khan         412          Sunrisers Hyderabad             17
# 6         K Rabada         401               Delhi Capitals             25
# 7          S Gopal         354             Rajasthan Royals             20
# 8  Harbhajan Singh         325          Chennai Super Kings             16
# 9          K Ahmed         310          Sunrisers Hyderabad             19

# %%
bowling_average_2019['bowling_average'] = round((bowling_average_2019['total_runs']/bowling_average_2019['total_wickets']),2)
bowling_average_2019 = bowling_average_2019.sort_values(by = "bowling_average",ascending = True)
bowling_average_2019
# Out:
#             bowler  total_runs                 bowling_team  total_wickets  \
# 6         K Rabada         401               Delhi Capitals             25
# 9          K Ahmed         310          Sunrisers Hyderabad             19
# 3      Imran Tahir         454          Chennai Super Kings             26
# 7          S Gopal         354             Rajasthan Royals             20
# 8  Harbhajan Singh         325          Chennai Super Kings             16
# 0        DL Chahar         503          Chennai Super Kings             22
# 4        YS Chahal         414  Royal Challengers Bangalore             18
# 2        JJ Bumrah         459               Mumbai Indians             19
# 5      Rashid Khan         412          Sunrisers Hyderabad             17
# 1   Mohammed Shami         493              Kings XI Punjab             19
#
#    bowling_average
# 6            16.04
# 9            16.32
# 3            17.46
# 7            17.70
# 8            20.31
# 0            22.86
# ...

# %%
totalballsspelt_2019['total_overs_spelt'] = totalballsspelt_2019['balls_spelt']/6
totalballsspelt_2019
# Out:
#               bowler  balls_spelt  total_overs_spelt
# 20         DL Chahar          403          67.166667
# 32       Imran Tahir          389          64.833333
# 38         JJ Bumrah          381          63.500000
# 10           B Kumar          367          61.166667
# 76       Rashid Khan          367          61.166667
# 70          R Ashwin          343          57.166667
# 60    Mohammed Shami          331          55.166667
# 74         RA Jadeja          329          54.833333
# 103        YS Chahal          308          51.333333
# 6           AR Patel          307          51.166667
# 63           N Saini          300          50.000000
# 43          K Rabada          297          49.500000
# 79           S Gopal          289          48.166667
# 75         RD Chahar          287          47.833333
# 30          I Sharma          286          47.666667
# 45         KH Pandya          282          47.000000
# 89        SL Malinga          280          46.666667
# ...

# %%
Bowling_Economy_2019 = pd.merge(totalruns_conceded_2019,totalballsspelt_2019,on = 'bowler')
Bowling_Economy_2019
# Out:
#              bowler  total_runs  balls_spelt  total_overs_spelt
# 0         DL Chahar         503          403          67.166667
# 1    Mohammed Shami         493          331          55.166667
# 2           B Kumar         485          367          61.166667
# 3        SL Malinga         477          280          46.666667
# 4         JJ Bumrah         459          381          63.500000
# 5       Imran Tahir         454          389          64.833333
# 6           N Saini         434          300          50.000000
# 7        JD Unadkat         422          236          39.333333
# 8         HH Pandya         418          269          44.833333
# 9          R Ashwin         416          343          57.166667
# 10        YS Chahal         414          308          51.333333
# 11        P Krishna         414          260          43.333333
# 12      Rashid Khan         412          367          61.166667
# 13        PP Chawla         411          267          44.500000
# ...

# %%
Bowling_Economy_2019['bowling_economy'] = round((Bowling_Economy_2019['total_runs']/Bowling_Economy_2019['total_overs_spelt']),2)
Bowling_Economy_2019 = Bowling_Economy_2019.sort_values(by='bowling_economy', ascending = True)
Bowling_Economy_2019
# Out:
#              bowler  total_runs  balls_spelt  total_overs_spelt  \
# 21        RA Jadeja         356          329          54.833333
# 29        RD Chahar         317          287          47.833333
# 12      Rashid Khan         412          367          61.166667
# 47            M Ali         171          152          25.333333
# 35         A Mishra         274          243          40.500000
# 5       Imran Tahir         454          389          64.833333
# 44    Mohammad Nabi         208          175          29.166667
# 4         JJ Bumrah         459          381          63.500000
# 28  Harbhajan Singh         325          269          44.833333
# 9          R Ashwin         416          343          57.166667
# 17         AR Patel         373          307          51.166667
# 24        KH Pandya         345          282          47.000000
# 22          S Gopal         354          289          48.166667
# 27         J Archer         327          265          44.166667
# ...

# %%
Bowling_df_2019 = Bowling_Economy_2019[Bowling_Economy_2019['balls_spelt']>100]
Bowling_df_2019 = Bowling_df_2019.sort_values(by = 'bowling_economy', ascending = True).head(20)
Bowling_df_2019
# Out:
#              bowler  total_runs  balls_spelt  total_overs_spelt  \
# 21        RA Jadeja         356          329          54.833333
# 29        RD Chahar         317          287          47.833333
# 12      Rashid Khan         412          367          61.166667
# 47            M Ali         171          152          25.333333
# 35         A Mishra         274          243          40.500000
# 5       Imran Tahir         454          389          64.833333
# 44    Mohammad Nabi         208          175          29.166667
# 4         JJ Bumrah         459          381          63.500000
# 28  Harbhajan Singh         325          269          44.833333
# 9          R Ashwin         416          343          57.166667
# 17         AR Patel         373          307          51.166667
# 24        KH Pandya         345          282          47.000000
# 22          S Gopal         354          289          48.166667
# 27         J Archer         327          265          44.166667
# ...

# %%
zero_run_balls_2019 = deliveries_2019[deliveries_2019['total_runs'] == 0]
zero_run_balls_2019
# Out:
#         match_id  inning                 batting_team         bowling_team  \
# 164751     11137       1  Royal Challengers Bangalore  Chennai Super Kings
# 164752     11137       1  Royal Challengers Bangalore  Chennai Super Kings
# 164753     11137       1  Royal Challengers Bangalore  Chennai Super Kings
# 164755     11137       1  Royal Challengers Bangalore  Chennai Super Kings
# 164763     11137       1  Royal Challengers Bangalore  Chennai Super Kings
# ...          ...     ...                          ...                  ...
# 179057     11415       2          Chennai Super Kings       Mumbai Indians
# 179064     11415       2          Chennai Super Kings       Mumbai Indians
# 179067     11415       2          Chennai Super Kings       Mumbai Indians
# 179069     11415       2          Chennai Super Kings       Mumbai Indians
# 179077     11415       2          Chennai Super Kings       Mumbai Indians
#
# ...

# %%
dismissed_balls_2019 = deliveries_2019[deliveries_2019['player_dismissed'].notna()]
dismissed_balls_2019
# Out:
#         match_id  inning                 batting_team         bowling_team  \
# 164771     11137       1  Royal Challengers Bangalore  Chennai Super Kings
# 164782     11137       1  Royal Challengers Bangalore  Chennai Super Kings
# 164794     11137       1  Royal Challengers Bangalore  Chennai Super Kings
# 164798     11137       1  Royal Challengers Bangalore  Chennai Super Kings
# 164806     11137       1  Royal Challengers Bangalore  Chennai Super Kings
# ...          ...     ...                          ...                  ...
# 179019     11415       2          Chennai Super Kings       Mumbai Indians
# 179033     11415       2          Chennai Super Kings       Mumbai Indians
# 179067     11415       2          Chennai Super Kings       Mumbai Indians
# 179075     11415       2          Chennai Super Kings       Mumbai Indians
# 179077     11415       2          Chennai Super Kings       Mumbai Indians
#
#         over  ball         batsman non_striker           bowler  \
# ...

# %%
dot_balls_2019 = zero_run_balls_2019[~zero_run_balls_2019.index.isin(dismissed_balls_2019.index)]
dot_balls_2019
# Out:
#         match_id  inning                 batting_team         bowling_team  \
# 164751     11137       1  Royal Challengers Bangalore  Chennai Super Kings
# 164752     11137       1  Royal Challengers Bangalore  Chennai Super Kings
# 164753     11137       1  Royal Challengers Bangalore  Chennai Super Kings
# 164755     11137       1  Royal Challengers Bangalore  Chennai Super Kings
# 164763     11137       1  Royal Challengers Bangalore  Chennai Super Kings
# ...          ...     ...                          ...                  ...
# 179046     11415       2          Chennai Super Kings       Mumbai Indians
# 179056     11415       2          Chennai Super Kings       Mumbai Indians
# 179057     11415       2          Chennai Super Kings       Mumbai Indians
# 179064     11415       2          Chennai Super Kings       Mumbai Indians
# 179069     11415       2          Chennai Super Kings       Mumbai Indians
#
# ...

# %%
dot_balls_by_player_2019 = dot_balls_2019.groupby('bowler')['total_runs'].count().reset_index()
dot_balls_by_player_2019.columns = ['bowler','dotball_count']
dot_balls_by_player_2019 = dot_balls_by_player_2019.sort_values(by = 'dotball_count',ascending = False)
dot_balls_by_player_2019
# Out:
#            bowler  dotball_count
# 19      DL Chahar            167
# 9         B Kumar            149
# 74    Rashid Khan            142
# 36      JJ Bumrah            135
# 61        N Saini            124
# ..            ...            ...
# 86       SK Raina              1
# 18       DJ Hooda              1
# 42    KC Cariappa              1
# 56  Mandeep Singh              1
# 99      YK Pathan              1
#
# [101 rows x 2 columns]

# %%
Dotball_merge_2019 = pd.merge(totalballsspelt_2019,dot_balls_by_player_2019,on = 'bowler')
Dotball_merge_2019 = Dotball_merge_2019.sort_values(by = 'dotball_count',ascending = False)
Dotball_merge_2019
# Out:
#              bowler  balls_spelt  total_overs_spelt  dotball_count
# 0         DL Chahar          403          67.166667            167
# 3           B Kumar          367          61.166667            149
# 4       Rashid Khan          367          61.166667            142
# 2         JJ Bumrah          381          63.500000            135
# 10          N Saini          300          50.000000            124
# 1       Imran Tahir          389          64.833333            121
# 13        RD Chahar          287          47.833333            110
# 7         RA Jadeja          329          54.833333            109
# 22         J Archer          265          44.166667            101
# 14         I Sharma          286          47.666667            100
# 9          AR Patel          307          51.166667             97
# 19  Harbhajan Singh          269          44.833333             96
# 8         YS Chahal          308          51.333333             95
# ...

# %%
Dotball_merge_2019['dotball_percentage'] = round((Dotball_merge_2019['dotball_count']/Dotball_merge_2019['balls_spelt'])*100,2)
Dotball_merge_2019 = Dotball_merge_2019.sort_values(by = 'dotball_percentage', ascending = False).head(10)
Dotball_merge_2019['dotball_percentage'] = Dotball_merge_2019['dotball_percentage'].astype(str) + '%'
Dotball_merge_2019
# Out:
#              bowler  balls_spelt  total_overs_spelt  dotball_count  \
# 0         DL Chahar          403          67.166667            167
# 10          N Saini          300          50.000000            124
# 3           B Kumar          367          61.166667            149
# 48    J Behrendorff          117          19.500000             46
# 4       Rashid Khan          367          61.166667            142
# 13        RD Chahar          287          47.833333            110
# 22         J Archer          265          44.166667            101
# 41            M Ali          152          25.333333             56
# 49   MJ McClenaghan          114          19.000000             41
# 19  Harbhajan Singh          269          44.833333             96
#
#    dotball_percentage
# 0              41.44%
# 10             41.33%
# 3               40.6%
# 48             39.32%
# 4              38.69%
# 13             38.33%
# 22             38.11%
# 41             36.84%
# ...

# %%
run_outs_2019 = deliveries_2019[deliveries_2019['dismissal_kind'] == "run out"]
run_outs_2019
# Out:
#         match_id  inning                 batting_team  \
# 164798     11137       1  Royal Challengers Bangalore
# 165362     11139       2               Mumbai Indians
# 165658     11140       2             Rajasthan Royals
# 165698     11140       2             Rajasthan Royals
# 166345     11143       2  Royal Challengers Bangalore
# 166992     11146       1        Kolkata Knight Riders
# 167060     11146       1        Kolkata Knight Riders
# 167183     11146       2               Delhi Capitals
# 167299     11147       1          Sunrisers Hyderabad
# 167352     11147       2  Royal Challengers Bangalore
# 167421     11147       2  Royal Challengers Bangalore
# 167731     11149       1              Kings XI Punjab
# 167810     11149       1              Kings XI Punjab
# 167917     11149       2               Delhi Capitals
# 169242     11310       1               Mumbai Indians
# 169936     11313       1          Sunrisers Hyderabad
# ...

# %%
len(run_outs_2019)
# Out:
# 39

# %%
most_runouts_2019 = run_outs_2019.groupby('fielder')['player_dismissed'].count().reset_index()
most_runouts_2019.columns = ["fielder","total_runouts"]
most_runouts_2019 = most_runouts_2019.sort_values(by="total_runouts",ascending = False).head(10)
most_runouts_2019
# Out:
#        fielder  total_runouts
# 31   V Shankar              3
# 19    R Ashwin              3
# 8     K Rabada              2
# 25    S Dhawan              2
# 20     R Singh              1
# 21   RG Sharma              1
# 22     RR Pant              1
# 23  RV Uthappa              1
# 24    S Curran              1
# 0    AT Rayudu              1

# %%
most_runouts_2019 = run_outs_2019.groupby('fielder')['player_dismissed'].count().reset_index()
most_runouts_2019.columns = ["fielder","total_runouts"]
most_runouts_2019 = most_runouts_2019.sort_values(by="total_runouts",ascending = False).head(10)
most_runouts_2019
# Out:
#        fielder  total_runouts
# 31   V Shankar              3
# 19    R Ashwin              3
# 8     K Rabada              2
# 25    S Dhawan              2
# 20     R Singh              1
# 21   RG Sharma              1
# 22     RR Pant              1
# 23  RV Uthappa              1
# 24    S Curran              1
# 0    AT Rayudu              1

# %%
most_runouts_2019 = run_outs_2019.groupby('batsman')['player_dismissed'].count().reset_index()
most_runouts_2019.columns = ["batsman","total_runouts"]
most_runouts_2019 = most_runouts_2019.sort_values(by="total_runouts",ascending = False).head(10)
most_runouts_2019
# Out:
#        batsman  total_runouts
# 29   SV Samson              2
# 28   SR Watson              2
# 3     AR Patel              2
# 4     AS Yadav              2
# 16    MS Dhoni              2
# 20   PP Chawla              2
# 14  KD Karthik              2
# 8    DA Warner              2
# 13  KA Pollard              2
# 22      S Dube              1

# %%
stumped_outs_2019 = deliveries_2019[deliveries_2019['dismissal_kind'] == "stumped"]
stumped_outs_2019
# Out:
#         match_id  inning                 batting_team  \
# 167333     11147       2  Royal Challengers Bangalore
# 169488     11311       1  Royal Challengers Bangalore
# 170162     11314       1        Kolkata Knight Riders
# 170194     11314       1        Kolkata Knight Riders
# 171348     11319       1              Kings XI Punjab
# 172227     11322       2               Mumbai Indians
# 173507     11328       1              Kings XI Punjab
# 173596     11328       1              Kings XI Punjab
# 174377     11331       2               Delhi Capitals
# 174533     11332       1          Sunrisers Hyderabad
# 174633     11332       2          Chennai Super Kings
# 176657     11341       2               Delhi Capitals
# 176659     11341       2               Delhi Capitals
# 177237     11344       1             Rajasthan Royals
# 178177     11412       1          Chennai Super Kings
# 178977     11415       2          Chennai Super Kings
#
# ...

# %%
len(stumped_outs_2019)
# Out:
# 16

# %%
most_stumped_2019 = stumped_outs_2019.groupby('fielder')['player_dismissed'].count().reset_index()
most_stumped_2019.columns = ["fielder","total_stumped"]
most_stumped_2019 = most_stumped_2019.sort_values(by="total_stumped",ascending = False).head(10)
most_stumped_2019
# Out:
#       fielder  total_stumped
# 1    MS Dhoni              5
# 4     RR Pant              4
# 0  J Bairstow              2
# 2    PA Patel              2
# 3   Q de Kock              2
# 5   SV Samson              1

# %%
most_stumped_2019 = stumped_outs_2019.groupby('batsman')['player_dismissed'].count().reset_index()
most_stumped_2019.columns = ["batsman","total_stumped"]
most_stumped_2019 = most_stumped_2019.sort_values(by="total_stumped",ascending = False).head(10)
most_stumped_2019
# Out:
#          batsman  total_stumped
# 4       KL Rahul              2
# 0      CH Morris              1
# 1      DA Warner              1
# 2   F du Plessis              1
# 3   Ishan Kishan              1
# 5          M Ali              1
# 6        M Vijay              1
# 7  Mandeep Singh              1
# 8      PP Chawla              1
# 9       S Dhawan              1

# %%
catch_outs_2019 = deliveries_2019[deliveries_2019['dismissal_kind'] == "caught"]
catch_outs_2019
# Out:
#         match_id  inning                 batting_team         bowling_team  \
# 164771     11137       1  Royal Challengers Bangalore  Chennai Super Kings
# 164782     11137       1  Royal Challengers Bangalore  Chennai Super Kings
# 164794     11137       1  Royal Challengers Bangalore  Chennai Super Kings
# 164806     11137       1  Royal Challengers Bangalore  Chennai Super Kings
# 164813     11137       1  Royal Challengers Bangalore  Chennai Super Kings
# ...          ...     ...                          ...                  ...
# 178908     11415       1               Mumbai Indians  Chennai Super Kings
# 178921     11415       1               Mumbai Indians  Chennai Super Kings
# 178945     11415       1               Mumbai Indians  Chennai Super Kings
# 179019     11415       2          Chennai Super Kings       Mumbai Indians
# 179067     11415       2          Chennai Super Kings       Mumbai Indians
#
# ...

# %%
len(catch_outs_2019)
# Out:
# 487

# %%
most_caughtplayer_2019 = catch_outs_2019.groupby('fielder')['player_dismissed'].count().reset_index()
most_caughtplayer_2019.columns = ["fielder","total_caught"]
most_caughtplayer_2019 = most_caughtplayer_2019.sort_values(by="total_caught",ascending = False).head(10)
most_caughtplayer_2019
# Out:
#           fielder  total_caught
# 84        RR Pant            18
# 74      Q de Kock            17
# 26   F du Plessis            12
# 60       MS Dhoni            11
# 29      HH Pandya            11
# 112     V Shankar            10
# 22       DJ Hooda            10
# 80      RA Jadeja             9
# 35     J Bairstow             9
# 7        AR Patel             9

# %%
most_caughtplayer_2019 = catch_outs_2019.groupby('batsman')['player_dismissed'].count().reset_index()
most_caughtplayer_2019.columns = ["batsman","total_caught"]
most_caughtplayer_2019 = most_caughtplayer_2019.sort_values(by="total_caught",ascending = False).head(10)
most_caughtplayer_2019
# Out:
#        batsman  total_caught
# 105    V Kohli            13
# 72    PA Patel            12
# 71      P Shaw            12
# 17    CH Gayle            12
# 106  V Shankar            11
# 46   KH Pandya            11
# 74   Q de Kock            11
# 88    S Dhawan            10
# 16     CA Lynn            10
# 84     RR Pant            10

# %%
bowled_outs_2019 = deliveries_2019[deliveries_2019['dismissal_kind'] == "bowled"]
bowled_outs_2019
# Out:
#         match_id  inning                 batting_team  \
# 164851     11137       1  Royal Challengers Bangalore
# 164866     11137       2          Chennai Super Kings
# 164941     11137       2          Chennai Super Kings
# 165043     11138       1          Sunrisers Hyderabad
# 165071     11138       1          Sunrisers Hyderabad
# ...          ...     ...                          ...
# 178437     11413       1          Sunrisers Hyderabad
# 178700     11414       1               Delhi Capitals
# 178710     11414       1               Delhi Capitals
# 178811     11414       2          Chennai Super Kings
# 178901     11415       1               Mumbai Indians
#
#                        bowling_team  over  ball        batsman   non_striker  \
# 164851          Chennai Super Kings    17     5       UT Yadav      PA Patel
# 164866  Royal Challengers Bangalore     3     1      SR Watson     AT Rayudu
# 164941  Royal Challengers Bangalore    15     2      AT Rayudu     KM Jadhav
# ...

# %%
len(bowled_outs_2019)
# Out:
# 86

# %%
most_bowled_2019 = bowled_outs_2019.groupby('bowler')['player_dismissed'].count().reset_index()
most_bowled_2019.columns = ["bowler","total_bowled"]
most_bowled_2019 = most_bowled_2019.sort_values(by="total_bowled",ascending = False).head(10)
most_bowled_2019
# Out:
#             bowler  total_bowled
# 26  Mohammed Shami             6
# 42       YS Chahal             4
# 35        S Curran             4
# 31        R Ashwin             4
# 22       KH Pandya             4
# 14        I Sharma             3
# 34     Rashid Khan             3
# 33       RD Chahar             3
# 32       RA Jadeja             3
# 30       PP Chawla             3

# %%
most_bowled_2019 = bowled_outs_2019.groupby('batsman')['player_dismissed'].count().reset_index()
most_bowled_2019.columns = ["batsman","total_bowled"]
most_bowled_2019 = most_bowled_2019.sort_values(by="total_bowled",ascending = False).head(10)
most_bowled_2019
# Out:
#           batsman  total_bowled
# 48       SK Raina             4
# 51      SR Watson             4
# 4       AT Rayudu             3
# 52        SS Iyer             3
# 29     MA Agarwal             2
# 13       DJ Hooda             2
# 44       S Dhawan             2
# 26  L Livingstone             2
# 21         K Paul             2
# 35         P Shaw             2

# %%
lbw_outs_2019 = deliveries_2019[deliveries_2019['dismissal_kind'] == "lbw"]
lbw_outs_2019
# Out:
#         match_id  inning                 batting_team  \
# 165181     11138       2        Kolkata Knight Riders
# 165777     11141       1               Delhi Capitals
# 166669     11144       2          Sunrisers Hyderabad
# 166725     11145       1               Mumbai Indians
# 166731     11145       1               Mumbai Indians
# 166772     11145       1               Mumbai Indians
# 166959     11146       1        Kolkata Knight Riders
# 166973     11146       1        Kolkata Knight Riders
# 167699     11149       1              Kings XI Punjab
# 167711     11149       1              Kings XI Punjab
# 167875     11149       2               Delhi Capitals
# 168104     11150       2             Rajasthan Royals
# 168597     11152       2          Sunrisers Hyderabad
# 168717     11153       1  Royal Challengers Bangalore
# 169194     11310       1               Mumbai Indians
# 169516     11311       1  Royal Challengers Bangalore
# ...

# %%
len(lbw_outs_2019)
# Out:
# 46

# %%
most_lbw_2019 = lbw_outs_2019.groupby('bowler')['player_dismissed'].count().reset_index()
most_lbw_2019.columns = ["bowler","total_lbw"]
most_lbw_2019 = most_lbw_2019.sort_values(by="total_lbw",ascending = False).head(10)
most_lbw_2019
# Out:
#           bowler  total_lbw
# 3      DL Chahar          5
# 22   Rashid Khan          4
# 12         M Ali          3
# 10     JJ Bumrah          3
# 28     YS Chahal          2
# 25      S Sharma          2
# 24  S Lamichhane          2
# 27     SP Narine          2
# 4       H Gurney          2
# 2      CH Morris          2

# %%
most_lbw_2019 = lbw_outs_2019.groupby('batsman')['player_dismissed'].count().reset_index()
most_lbw_2019.columns = ["batsman","total_lbw"]
most_lbw_2019 = most_lbw_2019.sort_values(by="total_lbw",ascending = False)
most_lbw_2019
# Out:
#            batsman  total_lbw
# 1        AM Rahane          4
# 22       RG Sharma          3
# 21       Q de Kock          2
# 2         AS Yadav          2
# 4         C Ingram          2
# 7        HH Pandya          2
# 29        SK Raina          2
# 25        S Curran          2
# 11       KM Jadhav          2
# 26        S Dhawan          1
# 23         RR Pant          1
# 24      RV Uthappa          1
# 0         A Turner          1
# 27          S Gill          1
# 20        PA Patel          1
# 30       SN Thakur          1
# 31       SR Watson          1
# 32         SS Iyer          1
# 28         S Singh          1
# 17          N Naik          1
# 19          P Shaw          1
# 18          N Rana          1
# 16  Mohammed Siraj          1
# 15        MS Dhoni          1
# 14       MK Pandey          1
# 13      MJ Guptill          1
# 12   KS Williamson          1
# 10        KL Rahul          1
# 9           K Paul          1
# 8       J Bairstow          1
# ...

# %%
pip install nbconvert
